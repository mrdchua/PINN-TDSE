# %% [markdown]
# 1. Data Generation

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime

# use float64 for higher precision in PDEs
tf.keras.backend.set_floatx('float64')
DTYPE = tf.float64

# declare inputs
# w_min, w_max = tf.constant(0.75, dtype=DTYPE), tf.constant(2.0, dtype=DTYPE)
w_choice = tf.constant(1.0, dtype=DTYPE)
pi = tf.constant(np.pi, dtype=DTYPE)
x_min, x_max = -pi, pi
t_min, t_max = tf.constant(0.0, dtype=DTYPE), 2.0*pi

# scale inputs
@tf.function
def scale_inputs(input, input_min, input_max):
    return 2.0 * (input - input_min) / (input_max - input_min) - 1.0

# # renormalization
# @tf.function
# def normalization(input_min, input_max, N, psi_Re, psi_Im):
#     dx = (input_max - input_min) / tf.cast(N, dtype=DTYPE)
#     norm = tf.math.sqrt(tf.reduce_sum(psi_Re**2 + psi_Im**2) * dx)
#     return (psi_Re/norm), (psi_Im/norm)

# initial condition
@tf.function
def psi_init(x, w, pi):
    u_0 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2)
    u_1 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2) * x * tf.math.sqrt(2.0*w)
    return (1.0/np.sqrt(2.0)) * (u_0 + u_1)

# data generation
N_f, N_b, N_i, N_grid = 5000, 500, 500, 100

# interior points
x_f = tf.random.uniform((N_f, 1), x_min, x_max, dtype=DTYPE)
t_f = tf.random.uniform((N_f, 1), t_min, t_max, dtype=DTYPE)
x_fs = scale_inputs(x_f, x_min, x_max)  # scaled
t_fs = scale_inputs(t_f, t_min, t_max)  # scaled

# boundary points
x_b = tf.concat([tf.ones((N_b//2, 1), dtype=DTYPE) * x_min,
                 tf.ones((N_b//2, 1), dtype=DTYPE) * x_max], axis=0)
t_b = tf.random.uniform((N_b, 1), t_min, t_max, dtype=DTYPE)
x_bs = scale_inputs(x_b, x_min, x_max)  # scaled
t_bs = scale_inputs(t_b, t_min, t_max)  # scaled

# initial points
x_i = tf.random.uniform((N_i, 1), x_min, x_max, dtype=DTYPE)
t_i = tf.zeros_like(x_i, dtype=DTYPE)
x_is = scale_inputs(x_i, x_min, x_max)  # scaled
t_is = scale_inputs(t_i, t_min, t_max)  # scaled

psi_i = tf.cast(psi_init(x_i, w_choice, pi), tf.complex128)

# grid for normalization penalty
x_n = tf.linspace(x_min, x_max, N_grid)[:, None]
x_ns = scale_inputs(x_n, x_min, x_max)

# %%
# check shapes and data types
print('x_is')
print(tf.shape(x_is))
print(x_is.dtype)
print(tf.shape(t_is))
print(t_is.dtype)

print('x_bs')
print(tf.shape(x_bs))
print(x_bs.dtype)
print(tf.shape(t_bs))
print(t_bs.dtype)

print('x_fs')
print(tf.shape(x_fs))
print(x_fs.dtype)
print(tf.shape(t_fs))
print(t_fs.dtype)

print('psi_i')
print(tf.shape(psi_i))
print(psi_i.dtype)

print('x_ns')
print(tf.shape(x_ns))
print(x_ns.dtype)

# %%
plt.scatter(x_fs, t_fs, alpha=0.5, linewidths=1e-6, label=f'{N_f} collocation points')
plt.scatter(x_bs, t_bs, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(x_is, t_is, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Scaled Inputs')
plt.legend(loc='upper right')
plt.show()

plt.scatter(x_i, tf.math.abs(psi_i)**2, alpha=0.5, linewidths=1e-6, label=f'$|\Psi(x,{float(t_i[0])})|^2$')
plt.xlabel('x')
plt.title(f'$|\Psi(x,{float(t_i[0])})|^2$ at $\omega={w_choice}$')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# 2. Model Architecture

# %%
# Fourier feature layer
@tf.keras.utils.register_keras_serializable()
class FourierFeatureLayer(tf.keras.layers.Layer):
    def __init__(self, input_dim, mapping_size=512, scale=10.0, **kwargs):
        super(FourierFeatureLayer, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

    def build(self, input_shape):
        self.B = self.add_weight(name="B",
                                 shape=[self.input_dim, self.mapping_size],
                                 initializer=tf.random_normal_initializer(stddev=self.scale),
                                 trainable=False)
    
    def call(self, x):
        x_proj = tf.matmul(x, self.B)
        return tf.concat([tf.math.sin(x_proj), tf.math.cos(x_proj)], axis=-1)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config
    
# Define the Neural Network
@tf.keras.utils.register_keras_serializable()
class PINN(tf.keras.Model):
    def __init__(self, input_dim=2, mapping_size=512, scale=10.0, **kwargs):
        super(PINN, self).__init__(**kwargs)

        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

        self.fourier = FourierFeatureLayer(input_dim=input_dim, mapping_size=mapping_size, scale=scale)
        initializer = tf.keras.initializers.GlorotNormal()

        self.dense1 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense2 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense3 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense4 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.out = tf.keras.layers.Dense(2, activation='linear', kernel_initializer=initializer) # u_Re, u_Im
        
    def call(self, x):
        x = self.fourier(x)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.out(x)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)
    
# We use Hartree atomic units \hbar = m = 1
# Define the Physics Loss
@tf.function
def pde_residual(model, x, t):
    with tf.GradientTape(persistent=True) as tape2:
        tape2.watch([x, t])
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch([x, t])
            xs = scale_inputs(x, x_min, x_max)
            ts = scale_inputs(t, t_min, t_max)
            X = tf.concat([xs, ts], axis=1)
            # uv = tf.clip_by_value(model(X), -1e2, 1e2) # prevent extreme values
            uv = model(X)
            u, v = uv[:, 0:1], uv[:, 1:2]
        u_x = tape1.gradient(u, x) #, unconnected_gradients='zero')
        v_x = tape1.gradient(v, x) #, unconnected_gradients='zero')
        u_t = tape1.gradient(u, t) #, unconnected_gradients='zero')
        v_t = tape1.gradient(v, t) #, unconnected_gradients='zero')
    u_xx = tape2.gradient(u_x, x) #, unconnected_gradients='zero')
    v_xx = tape2.gradient(v_x, x) #, unconnected_gradients='zero')
    del tape1, tape2

    potential = 0.5 * w_choice**2 * x**2

    f_u = -v_t + 0.5*u_xx - potential*u
    f_v = u_t + 0.5*v_xx - potential*v

    return f_u, f_v

@tf.function
def norm_loss(model, x_ns, N_t):
    t_n = tf.random.uniform((N_t, 1), t_min, t_max, dtype=DTYPE)
    t_ns = scale_inputs(t_n, t_min, t_max)
    norm_penalty_total = 0.0
    for t_val in tf.unstack(t_ns, axis=0):
        t_in = tf.ones_like(x_ns) * t_val
        X = tf.concat([x_ns, t_in], axis=1)
        uv = model(X)
        dx = (x_max - x_min) / tf.cast(tf.shape(x_ns)[0], dtype=DTYPE)
        norm = tf.reduce_sum(tf.math.abs(uv)**2) * dx
        norm_penalty_total += tf.square(norm - 1.0)
    norm_penalty = norm_penalty_total / tf.cast(N_t, dtype=DTYPE)

    return norm_penalty

@tf.function
def loss_fn(model, interior, boundary, initial, norm_grid):
    x_f, t_f = interior
    x_b, t_b = boundary
    x_i, t_i, psi_i = initial
    x_grid, N_t = norm_grid

    f_u, f_v = pde_residual(model, x_f, t_f)
    loss_f = tf.reduce_mean(tf.square(f_u) + tf.square(f_v)) # / tf.cast(tf.shape(x_f)[0], dtype=DTYPE)

    uv_b = model(tf.concat([x_b, t_b], axis=1))
    loss_b = tf.reduce_mean(tf.square(uv_b[:, 0:1]) + tf.square(uv_b[:, 1:2])) # / tf.cast(tf.shape(x_b)[0], dtype=DTYPE)

    uv_i = model(tf.concat([x_i, t_i], axis=1))
    loss_i = tf.reduce_mean(tf.square(uv_i[:, 0:1] - tf.math.real(psi_i)) +
                            tf.square(uv_i[:, 1:2] - tf.math.imag(psi_i))) # / tf.cast(tf.shape(x_i)[0], dtype=DTYPE)
    
    norm_penalty = norm_loss(model, x_grid, N_t)
    
    return loss_f + 100.0*loss_b + 100.0*loss_i + norm_penalty, (loss_f, 100.0*loss_b, 100.0*loss_i, norm_penalty)

# %%
# Create the model
model = PINN(input_dim=2, mapping_size=512, scale=10.0)

# Save the model in Keras format
model_test_path = 'model_test_w1.keras'
model.save(model_test_path)
print(f"Model saved to {model_test_path}")

# Load the model
loaded_model = tf.keras.models.load_model(model_test_path, custom_objects={'PINN': PINN})

# Dummy input to build the model (batch size 1, input_dim = 2)
dummy_input = tf.concat([x_f[:5], t_f[:5]], axis=1)
_ = loaded_model(dummy_input)

loaded_model.summary()

# %% [markdown]
# 3. Optimizer and Step Function

# %%
# Define the Optimizer
# Learning rate schedule with exponential decay
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=2000,
    decay_rate=0.9,
    staircase=True
)

# ADAM optimizer
optimizer = tf.keras.optimizers.Adam(
    learning_rate=lr_schedule,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    clipnorm=1.0
)

# Training Step Function
@tf.function
def train_step(model, x_f, t_f, x_b, t_b, x_i, t_i, psi_i, x_n, N_t):
    with tf.GradientTape() as tape:
        loss, (lf, lb, li, ln) = loss_fn(model, (x_f, t_f), (x_b, t_b), (x_i, t_i, psi_i), (x_n, N_t))
        
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss, (lf, lb, li, ln)

# %% [markdown]
# 4. Training loop

# %%
# Instantiate the Model
pinn = PINN(input_dim=2, mapping_size=512, scale=10.0)

# pinn = tf.keras.models.load_model('best_model_s4v0.keras', custom_objects={'PINN': PINN})
# print("Model loaded successfully")

# Define the loss threshold
loss_threshold = 1e-10

# Early stopping
early_stopping_patience = 1000
best_loss = float('inf')
patience_counter = 0

# saving loss values
train_loss_results = {
    "total": [],
    "pde": [],
    "boundary": [],
    "initial": [],
    "norm" : []
}

# Start the timer
start_time = time.time()

best_model_path = "best_model_w1.keras"

# Training Loop until loss < loss_threshold
epoch = 0
while True:
    loss, (lf, lb, li, ln) = train_step(pinn, x_f, t_f, x_bs, t_bs, x_is, t_is, psi_i, x_ns, 3)

    train_loss_results["total"].append(loss.numpy())
    train_loss_results["pde"].append(lf.numpy())
    train_loss_results["boundary"].append(lb.numpy())
    train_loss_results["initial"].append(li.numpy())
    train_loss_results["norm"].append(ln.numpy())

    if epoch % 1000 == 0:
        print(f"Epoch {epoch}: Loss = {loss.numpy().item():.5e} (f = {lf.numpy().item():.3e}, b = {lb.numpy().item():.3e}, i = {li.numpy().item():.3e}, n = {ln.numpy().item():.3e})")

        X = tf.concat([x_is, t_is], axis=1)
        uv = pinn(X)
        u, v = uv[:, 0:1], uv[:, 1:2]
        # test_Re, test_Im = normalization(x_min, x_max, N_i, u, v)
        density = u**2 + v**2

        plt.scatter(x_i, density, label=r'$|\Psi(x,0)|^2$ with \omega=1.0')
        plt.xlabel('x')
        plt.legend()
        plt.show()
        
    if loss.numpy() < best_loss:
        best_loss = loss.numpy()
        patience_counter = 0
        pinn.save(best_model_path)
        print(f"Best model saved to {best_model_path} at epoch {epoch} with loss {loss.numpy()}")
    else:
        patience_counter += 1

    if patience_counter >= early_stopping_patience:
        print(f"Early stopping at epoch {epoch} as loss did not improve for {early_stopping_patience} epochs.")
        print(f"Training stopped at epoch {epoch} with loss {loss.numpy()}")
        break
    
    if loss.numpy() < loss_threshold:
        print(f"Training stopped at epoch {epoch} as loss reached {loss.numpy()}")
        break

    epoch += 1

# End the timer
end_time = time.time()

# Calculate total execution time
execution_time = end_time - start_time

# Convert to hours, minutes, seconds
execution_time_formatted = str(datetime.timedelta(seconds=int(execution_time)))

print(f"Total training time: {execution_time_formatted}")
        
# Plot the Loss vs. Epochs
plt.plot(train_loss_results["total"], label="Total Loss")
plt.plot(train_loss_results["pde"], label="PDE Loss")
plt.plot(train_loss_results["boundary"], label="Boundary Loss")
plt.plot(train_loss_results["initial"], label="Initial Loss")
plt.plot(train_loss_results["norm"], label="Norm Loss")
plt.yscale("log")
plt.legend()
plt.title("Loss Components During Training")
plt.xlabel("Epoch")
plt.ylabel("Loss (log scale)")
plt.grid(True)
plt.show()

# Save original weights
original_weights = pinn.get_weights()

# Load the model
loaded_pinn = tf.keras.models.load_model(best_model_path, custom_objects={'PINN': PINN})

# Check if the weights match
loaded_weights = loaded_pinn.get_weights()

for orig, loaded in zip(original_weights, loaded_weights):
    if not np.array_equal(orig, loaded):
        print("Weights do not match after loading!")
    else:
        print("Weights match.")
# Out:
# Epoch 0: Loss = 1.95017e+02 (f = 8.149e+01, b = 4.819e+01, i = 6.076e+01, n = 4.574e+00)
# Best model saved to best_model_w1.keras at epoch 0 with loss 195.01671270191093
# Best model saved to best_model_w1.keras at epoch 2 with loss 174.2644009025574
# Best model saved to best_model_w1.keras at epoch 4 with loss 151.12880375852097
# Best model saved to best_model_w1.keras at epoch 5 with loss 48.958924996238004
# Best model saved to best_model_w1.keras at epoch 6 with loss 40.11893761881493
# Best model saved to best_model_w1.keras at epoch 7 with loss 32.62867074485046
# Best model saved to best_model_w1.keras at epoch 8 with loss 26.299165456407742
# Best model saved to best_model_w1.keras at epoch 9 with loss 22.53818846168498
# Best model saved to best_model_w1.keras at epoch 10 with loss 16.73890852392392
# Best model saved to best_model_w1.keras at epoch 11 with loss 13.452050115563164
# Best model saved to best_model_w1.keras at epoch 12 with loss 12.73794943078039
# Best model saved to best_model_w1.keras at epoch 13 with loss 9.992779219999651
# Best model saved to best_model_w1.keras at epoch 14 with loss 8.824822008375337
# Best model saved to best_model_w1.keras at epoch 15 with loss 7.343095508830505
# Best model saved to best_model_w1.keras at epoch 16 with loss 5.517877502205317
# Best model saved to best_model_w1.keras at epoch 18 with loss 3.876137064596827
# Best model saved to best_model_w1.keras at epoch 24 with loss 3.729267023138556
# Best model saved to best_model_w1.keras at epoch 26 with loss 3.4517217746111886
# Best model saved to best_model_w1.keras at epoch 28 with loss 2.9339052141477806
# Best model saved to best_model_w1.keras at epoch 29 with loss 2.4025883168643833
# Best model saved to best_model_w1.keras at epoch 31 with loss 1.7977716733037172
# Best model saved to best_model_w1.keras at epoch 37 with loss 1.6588195862430672
# Best model saved to best_model_w1.keras at epoch 38 with loss 1.5647204822652603
# Best model saved to best_model_w1.keras at epoch 39 with loss 1.3353602758880705
# Best model saved to best_model_w1.keras at epoch 42 with loss 1.0952431552948163
# Best model saved to best_model_w1.keras at epoch 47 with loss 1.0875477307706343
# Best model saved to best_model_w1.keras at epoch 48 with loss 0.8915661682353897
# Best model saved to best_model_w1.keras at epoch 50 with loss 0.6561530277336762
# Best model saved to best_model_w1.keras at epoch 52 with loss 0.5173249671389989
# Best model saved to best_model_w1.keras at epoch 73 with loss 0.5124007833139708
# Best model saved to best_model_w1.keras at epoch 100 with loss 0.4677458844662151
# Best model saved to best_model_w1.keras at epoch 117 with loss 0.3366178106849789
# Best model saved to best_model_w1.keras at epoch 162 with loss 0.3015387142393635
# Best model saved to best_model_w1.keras at epoch 166 with loss 0.27142612850145925
# Best model saved to best_model_w1.keras at epoch 219 with loss 0.265157614286302
# Best model saved to best_model_w1.keras at epoch 247 with loss 0.2334654139965721
# Best model saved to best_model_w1.keras at epoch 253 with loss 0.16265361831596506
# Best model saved to best_model_w1.keras at epoch 307 with loss 0.16072376671341426
# Best model saved to best_model_w1.keras at epoch 313 with loss 0.1311970671919792
# Best model saved to best_model_w1.keras at epoch 374 with loss 0.11575415121905387
# Best model saved to best_model_w1.keras at epoch 470 with loss 0.10982307924919663
# Best model saved to best_model_w1.keras at epoch 488 with loss 0.10642637293892993
# Best model saved to best_model_w1.keras at epoch 522 with loss 0.0964651876481218
# Best model saved to best_model_w1.keras at epoch 528 with loss 0.09291178558138388
# Best model saved to best_model_w1.keras at epoch 530 with loss 0.07621206920993714
# Best model saved to best_model_w1.keras at epoch 577 with loss 0.06686650485923173
# Best model saved to best_model_w1.keras at epoch 587 with loss 0.050248435636480945
# Best model saved to best_model_w1.keras at epoch 679 with loss 0.043452794701483055
# Best model saved to best_model_w1.keras at epoch 744 with loss 0.040929707769114074
# Best model saved to best_model_w1.keras at epoch 776 with loss 0.04005011351219355
# Best model saved to best_model_w1.keras at epoch 779 with loss 0.03177177049919723
# Best model saved to best_model_w1.keras at epoch 799 with loss 0.03117553764988377
# Best model saved to best_model_w1.keras at epoch 810 with loss 0.029639879981989924
# Best model saved to best_model_w1.keras at epoch 813 with loss 0.027727823739508797
# Best model saved to best_model_w1.keras at epoch 817 with loss 0.027475552923569957
# Best model saved to best_model_w1.keras at epoch 819 with loss 0.023131462067167794
# Epoch 1000: Loss = 1.18234e-01 (f = 2.721e-02, b = 2.597e-02, i = 6.499e-02, n = 7.437e-05)
# Best model saved to best_model_w1.keras at epoch 1207 with loss 0.020893521365072863
# Best model saved to best_model_w1.keras at epoch 1242 with loss 0.020826426712772465
# Best model saved to best_model_w1.keras at epoch 1256 with loss 0.020629598396776493
# Best model saved to best_model_w1.keras at epoch 1257 with loss 0.017215825273850592
# Best model saved to best_model_w1.keras at epoch 1262 with loss 0.013613383607152148
# Best model saved to best_model_w1.keras at epoch 1269 with loss 0.011422407462665462
# Best model saved to best_model_w1.keras at epoch 1398 with loss 0.011123675137540912
# Best model saved to best_model_w1.keras at epoch 1399 with loss 0.009814423266493994
# Best model saved to best_model_w1.keras at epoch 1433 with loss 0.00957938579770725
# Best model saved to best_model_w1.keras at epoch 1434 with loss 0.00915689045833118
# Best model saved to best_model_w1.keras at epoch 1437 with loss 0.009121882369911129
# Best model saved to best_model_w1.keras at epoch 1439 with loss 0.008557603465413337
# Best model saved to best_model_w1.keras at epoch 1441 with loss 0.007685102314022014
# Best model saved to best_model_w1.keras at epoch 1442 with loss 0.007312004728889019
# Best model saved to best_model_w1.keras at epoch 1666 with loss 0.006035657166719301
# Best model saved to best_model_w1.keras at epoch 1670 with loss 0.004741673157201272
# Best model saved to best_model_w1.keras at epoch 1698 with loss 0.004481802357810857
# Best model saved to best_model_w1.keras at epoch 1700 with loss 0.004391714171463015
# Best model saved to best_model_w1.keras at epoch 1820 with loss 0.004005167805635936
# Epoch 2000: Loss = 4.26324e-01 (f = 3.318e-02, b = 4.863e-02, i = 3.435e-01, n = 1.000e-03)
# Best model saved to best_model_w1.keras at epoch 2287 with loss 0.0039717328492352355
# Best model saved to best_model_w1.keras at epoch 2289 with loss 0.003960800062902939
# Best model saved to best_model_w1.keras at epoch 2292 with loss 0.0039400269681012816
# Best model saved to best_model_w1.keras at epoch 2293 with loss 0.0033498613636662048
# Best model saved to best_model_w1.keras at epoch 2294 with loss 0.0029652902400266533
# Best model saved to best_model_w1.keras at epoch 2297 with loss 0.0024767849404300846
# Best model saved to best_model_w1.keras at epoch 2346 with loss 0.0022228849242152426
# Best model saved to best_model_w1.keras at epoch 2349 with loss 0.0020269743576172296
# Best model saved to best_model_w1.keras at epoch 2352 with loss 0.0018197052741464703
# Best model saved to best_model_w1.keras at epoch 2354 with loss 0.0015467195137811595
# Best model saved to best_model_w1.keras at epoch 2482 with loss 0.0014384609653464288
# Best model saved to best_model_w1.keras at epoch 2486 with loss 0.0012625426773849396
# Best model saved to best_model_w1.keras at epoch 2504 with loss 0.0011831137277855369
# Best model saved to best_model_w1.keras at epoch 2509 with loss 0.0011694591011049715
# Best model saved to best_model_w1.keras at epoch 2510 with loss 0.0010647789972258995
# Best model saved to best_model_w1.keras at epoch 2515 with loss 0.0010310858819109754
# Best model saved to best_model_w1.keras at epoch 2516 with loss 0.0008647082609004153
# Best model saved to best_model_w1.keras at epoch 2520 with loss 0.0008271228771633925
# Best model saved to best_model_w1.keras at epoch 2522 with loss 0.000750360778406349
# Best model saved to best_model_w1.keras at epoch 2523 with loss 0.0007171095733389883
# Best model saved to best_model_w1.keras at epoch 2524 with loss 0.0007129236538661245
# Best model saved to best_model_w1.keras at epoch 2942 with loss 0.0006829965912422163
# Best model saved to best_model_w1.keras at epoch 2975 with loss 0.0006354398825140011
# Best model saved to best_model_w1.keras at epoch 2979 with loss 0.0005245506992518305
# Best model saved to best_model_w1.keras at epoch 2988 with loss 0.0004741389375060778
# Best model saved to best_model_w1.keras at epoch 2989 with loss 0.00041475234252813287
# Best model saved to best_model_w1.keras at epoch 2994 with loss 0.0003664155318987782
# Epoch 3000: Loss = 8.38846e-04 (f = 4.264e-04, b = 1.194e-04, i = 1.969e-04, n = 9.610e-05)
# Early stopping at epoch 3994 as loss did not improve for 1000 epochs.
# Training stopped at epoch 3994 with loss 0.0024497378375772493
# Total training time: 4:40:24
# WARNING:tensorflow:From c:\Users\HP\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Weights match.
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!
# Weights do not match after loading!

# %%
import csv

# Save to CSV
with open("train_loss_results_w1.csv", "w", newline="") as f:
    writer = csv.writer(f)
    
    # Write header
    writer.writerow(["epoch", "total_loss", "pde_loss", "boundary_loss", "initial_loss", "norm_loss"])
    
    # Write data row by row
    for epoch, (total, pde, boundary, initial, norm) in enumerate(zip(
        train_loss_results["total"],
        train_loss_results["pde"],
        train_loss_results["boundary"],
        train_loss_results["initial"],
        train_loss_results["norm"]
    )):
        writer.writerow([epoch, total, pde, boundary, initial, norm])

# %%
import pandas as pd

df = pd.read_csv("train_loss_results_s4v0.csv")
print(df.head())
print(df.tail())
# Out:
#    epoch  total_loss    pde_loss  boundary_loss  initial_loss  norm_loss
# 0      0   67.185984   66.056450       0.228903      0.403406   0.497226
# 1      1  116.960255  112.390348       0.434565      0.662449   3.472894
# 2      2   87.729807   86.423477       0.243887      0.466097   0.596347
# 3      3   26.021388   25.571185       0.088502      0.266090   0.095611
# 4      4   18.159319   17.450682       0.057641      0.217687   0.433309
#       epoch  total_loss  pde_loss  boundary_loss  initial_loss  norm_loss
# 6590   6590    0.012818  0.004995       0.000357      0.006603   0.000863
# 6591   6591    0.016967  0.007378       0.000406      0.008225   0.000958
# 6592   6592    0.017668  0.005970       0.000340      0.008106   0.003252
# 6593   6593    0.020406  0.010251       0.000610      0.007067   0.002478
# 6594   6594    0.018693  0.009501       0.000576      0.006815   0.001802

# %% [markdown]
# 5. Loading the Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime

# use float64 for higher precision in PDEs
tf.keras.backend.set_floatx('float64')
DTYPE = tf.float64

# declare inputs
# w_min, w_max = tf.constant(0.75, dtype=DTYPE), tf.constant(2.0, dtype=DTYPE)
w_choice = tf.constant(1.0, dtype=DTYPE)
pi = tf.constant(np.pi, dtype=DTYPE)
x_min, x_max = -pi, pi
t_min, t_max = tf.constant(0.0, dtype=DTYPE), 2.0*pi

# scale inputs
@tf.function
def scale_inputs(input, input_min, input_max):
    return 2.0 * (input - input_min) / (input_max - input_min) - 1.0

# # renormalization
# @tf.function
# def normalization(input_min, input_max, N, psi_Re, psi_Im):
#     dx = (input_max - input_min) / tf.cast(N, dtype=DTYPE)
#     norm = tf.math.sqrt(tf.reduce_sum(psi_Re**2 + psi_Im**2) * dx)
#     return (psi_Re/norm), (psi_Im/norm)

# initial condition
@tf.function
def psi_init(x, w, pi):
    u_0 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2)
    u_1 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2) * x * tf.math.sqrt(2.0*w)
    return (1.0/np.sqrt(2.0)) * (u_0 + u_1)

# data generation
N_f, N_b, N_i, N_grid = 5000, 500, 500, 100

# interior points
x_f = tf.random.uniform((N_f, 1), x_min, x_max, dtype=DTYPE)
t_f = tf.random.uniform((N_f, 1), t_min, t_max, dtype=DTYPE)
x_fs = scale_inputs(x_f, x_min, x_max)  # scaled
t_fs = scale_inputs(t_f, t_min, t_max)  # scaled

# boundary points
x_b = tf.concat([tf.ones((N_b//2, 1), dtype=DTYPE) * x_min,
                 tf.ones((N_b//2, 1), dtype=DTYPE) * x_max], axis=0)
t_b = tf.random.uniform((N_b, 1), t_min, t_max, dtype=DTYPE)
x_bs = scale_inputs(x_b, x_min, x_max)  # scaled
t_bs = scale_inputs(t_b, t_min, t_max)  # scaled

# initial points
x_i = tf.random.uniform((N_i, 1), x_min, x_max, dtype=DTYPE)
t_i = tf.zeros_like(x_i, dtype=DTYPE)
x_is = scale_inputs(x_i, x_min, x_max)  # scaled
t_is = scale_inputs(t_i, t_min, t_max)  # scaled

psi_i = tf.cast(psi_init(x_i, w_choice, pi), tf.complex128)

# grid for normalization penalty
x_n = tf.linspace(x_min, x_max, N_grid)[:, None]
x_ns = scale_inputs(x_n, x_min, x_max)

# verify normalization
dx_i = (x_max - x_min) / N_i
norm_check = tf.reduce_sum(tf.math.abs(psi_i)**2) * dx_i
print(f'Normalization check for the initial condition: $|\Psi(x,0)|**2={norm_check}$')

# Fourier feature layer
@tf.keras.utils.register_keras_serializable()
class FourierFeatureLayer(tf.keras.layers.Layer):
    def __init__(self, input_dim, mapping_size=512, scale=10.0, **kwargs):
        super(FourierFeatureLayer, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

    def build(self, input_shape):
        self.B = self.add_weight(name="B",
                                 shape=[self.input_dim, self.mapping_size],
                                 initializer=tf.random_normal_initializer(stddev=self.scale),
                                 trainable=False)
    
    def call(self, x):
        x_proj = tf.matmul(x, self.B)
        return tf.concat([tf.math.sin(x_proj), tf.math.cos(x_proj)], axis=-1)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config
    
# Define the Neural Network
@tf.keras.utils.register_keras_serializable()
class PINN(tf.keras.Model):
    def __init__(self, input_dim=2, mapping_size=512, scale=10.0, **kwargs):
        super(PINN, self).__init__(**kwargs)

        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

        self.fourier = FourierFeatureLayer(input_dim=input_dim, mapping_size=mapping_size, scale=scale)
        initializer = tf.keras.initializers.GlorotNormal()

        self.dense1 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense2 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense3 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense4 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.out = tf.keras.layers.Dense(2, activation='linear', kernel_initializer=initializer) # u_Re, u_Im
        
    def call(self, x):
        x = self.fourier(x)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.out(x)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)
    
# Load the model
loaded_model = tf.keras.models.load_model('best_model_w1.keras', custom_objects={'PINN': PINN})
print("Model loaded successfully")

loaded_model.summary()

################## Plot: Contour Plot ###############################

# Contour Plot
N = 100
x_plot = np.linspace(x_min, x_max, N)[:,None]
t_plot = np.linspace(t_min, t_max, N)[:,None]
x_plot_scaled = scale_inputs(x_plot, x_min, x_max)
t_plot_scaled = scale_inputs(t_plot, t_min, t_max)
X_grid, T_grid = np.meshgrid(x_plot, t_plot)  # t and x grid

x_plot_in = tf.convert_to_tensor(x_plot_scaled, dtype=DTYPE)
t_plot_in = tf.convert_to_tensor(t_plot_scaled, dtype=DTYPE)

density_interior = []

count = 0
for t_val in tf.unstack(t_plot_in, axis=0):
    t_in = tf.ones_like(x_plot_in) * t_val
    input = tf.concat([x_plot_in, t_in], axis=1)
    uv = loaded_model(input)
    u, v = uv[:, 0], uv[:, 1]
    density = u**2 + v**2
    # psi_Re, psi_Im = normalization(x_min, x_max, N, u, v)
    # density = psi_Re**2 + psi_Im**2
    density_interior.append(density)

# plt.figure(figsize=(8, 5))
contour = plt.contourf(X_grid, T_grid, density_interior, levels=100, cmap="viridis")
plt.colorbar(contour, label=r'$|\Psi(x,t)|^2$')
plt.xlabel(r'$x$')
plt.ylabel(r'$t$')
plt.title(f'Predicted $|\Psi(x,t)|^2$ with $\omega={w_choice}$')
plt.tight_layout()
plt.show()

################## Plot: Initial Condition ###############################

X = tf.concat([x_is, t_is], axis=1)
uv = loaded_model(X)
u, v = uv[:, 0:1], uv[:, 1:2]
# psi_Re, psi_Im = normalization(x_min, x_max, N_i, u, v)
# density_initial = psi_Re**2 + psi_Im**2

plt.scatter(x_i, u**2 + v**2, label=r'Predicted $|\Psi(x,0)|^2$')
# plt.scatter(x_i, density_initial, label=r'Normalized Predicted $|\Psi(x,0)|^2$')
plt.scatter(x_i, tf.math.abs(psi_i)**2, label=r'Expected $|\Psi(x,0)|^2$')
plt.xlabel('x')
plt.legend()
plt.show()

################## Plot: Boundary Condition ###############################

X = tf.concat([x_bs, t_bs], axis=1)
uv = loaded_model(X)
u, v = uv[:, 0:1], uv[:, 1:2]
# psi_Re, psi_Im = normalization(x_min, x_max, N_b, u, v)
# density_boundary = psi_Re**2 + psi_Im**2

plt.scatter(t_b, u**2 + v**2, label=r'Predicted $|\Psi(x_b,t)|^2$')
# plt.scatter(t_b, density_boundary, label=r'Normalized Predicted $|\Psi(x_b,t)|^2$')
plt.xlabel('t')
plt.legend()
plt.show()
# Out:
# Normalization check for the initial condition: $|\Psi(x,0)|**2=0.9004044577664697$
# Model loaded successfully
# Model: "pinn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fourier_feature_layer_3         │ ?                      │         1,024 │
# │ (FourierFeatureLayer)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (5000, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (5000, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (5000, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (5000, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (5000, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,314,818 (10.03 MB)
#  Trainable params: 1,313,794 (10.02 MB)
#  Non-trainable params: 1,024 (8.00 KB)

# %%
x_true = np.linspace(x_min, x_max, 100)

# Compute theoretical |Psi(x,t)|^2 as before
def U_0(x, t):
    w = 1.0
    return np.exp(-1j * 0.5 * w * t) * (w/np.pi)**0.25 * np.exp(-w * x**2 / 2.0)

def U_1(x, t):
    w = 1.0
    return np.exp(-1j * 1.5 * w * t) * (w/np.pi)**0.25 * np.exp(-w * x**2 / 2.0) * x * np.sqrt(2.0*w)

# Define time steps
t_test = [0, np.pi, 2.0*np.pi]

# Create subplots
fig, axs = plt.subplots(1, len(t_test), figsize=(15, 5), sharey=True)

for i, t_val in enumerate(t_test):
    t_in = tf.ones_like(x_is) * t_val
    t_ins = scale_inputs(t_in, t_min, t_max)
    X = tf.concat([x_is, t_ins], axis=1)
    uv = loaded_model(X)
    u, v = uv[:, 0:1], uv[:, 1:2]
    # psi_Re, psi_Im = normalization(x_min, x_max, N_b, u, v)
    # density = psi_Re**2 + psi_Im**2

    t_true = np.ones_like(x_true) * t_val
    psi_true = (1.0 / np.sqrt(2.0)) * (U_0(x_true, t_true) + U_1(x_true, t_true))
    density_true = np.abs(psi_true)**2

    ax = axs[i]
    # ax.scatter(x_i, density, s=10, label="Normalized", alpha=0.7)
    ax.scatter(x_i, u**2 + v**2, s=10, label="Raw", alpha=0.5)
    ax.scatter(x_true, density_true, s=10, label="True", alpha=0.6)
    ax.set_title(f"$t = {t_val:.2f}$")
    ax.set_xlabel("x")
    if i == 0:
        ax.set_ylabel(r"$|\Psi(x,t)|^2$")
    ax.grid(True)

# Add a single legend and adjust layout
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', ncol=2)
fig.suptitle("Predicted $|\Psi(x,t)|^2$ at Different Time Steps", fontsize=14)
# plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()
