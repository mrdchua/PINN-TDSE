# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv
import time
import datetime

# use float64 for higher precision in PDEs
tf.keras.backend.set_floatx('float64')
DTYPE = tf.float64

# declare inputs (stage 1)
w_min, w_max = tf.constant(0.75, dtype=DTYPE), tf.constant(0.8, dtype=DTYPE)
# w_choice = tf.constant(1.0, dtype=DTYPE)
pi = tf.constant(np.pi, dtype=DTYPE)
x_min, x_max = -pi, pi
t_min, t_max = tf.constant(0.0, dtype=DTYPE), pi/4.0

# generate grid points
def generate_grid_samples(x_min, x_max, t_min, t_max, N_x, N_t):
    x = tf.linspace(x_min, x_max, N_x)
    t = tf.linspace(t_min, t_max, N_t)
    X, T = tf.meshgrid(x, t)
    x_flat = tf.reshape(X, [-1, 1])
    t_flat = tf.reshape(T, [-1, 1])
    return x_flat, t_flat

# scale inputs
# @tf.function
def scale_inputs(input, input_min, input_max):
    return 2.0 * (input - input_min) / (input_max - input_min) - 1.0

# # renormalization
# @tf.function
# def normalization(input_min, input_max, N, psi_Re, psi_Im):
#     dx = (input_max - input_min) / tf.cast(N, dtype=DTYPE)
#     norm = tf.math.sqrt(tf.reduce_sum(psi_Re**2 + psi_Im**2) * dx)
#     return (psi_Re/norm), (psi_Im/norm)

# initial condition
# @tf.function
def psi_init(x, w, pi):
    u_0 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2)
    u_1 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2) * x * tf.math.sqrt(2.0*w)
    return (1.0/np.sqrt(2.0)) * (u_0 + u_1)

# data generation
N_xt, N_b, N_i, N_grid = 70, 784, 900, 225

# interior points (stage 1)
x_f, t_f = generate_grid_samples(x_min, x_max, t_min, t_max, N_xt, N_xt)
w_f = tf.ones_like(x_f) * w_min
# w_f = tf.linspace(w_min, w_max, N_xt*N_xt)[:, None]
x_fs = scale_inputs(x_f, x_min, x_max)  # scaled
t_fs = scale_inputs(t_f, t_min, t_max)  # scaled
w_fs = scale_inputs(w_f, w_min, w_max)  # scaled

# boundary points (stage 1)
x_b = tf.concat([tf.ones((N_b//2, 1), dtype=DTYPE) * x_min,
                 tf.ones((N_b//2, 1), dtype=DTYPE) * x_max], axis=0)
t_b = tf.linspace(t_min, t_max, N_b//2)[:, None]
t_b = tf.tile(t_b, [2, 1])
w_b = tf.ones_like(x_b) * w_min
# w_b = tf.linspace(w_min, w_max, N_b//2)[:, None]
# w_b = tf.tile(w_b, [2, 1])
x_bs = scale_inputs(x_b, x_min, x_max)  # scaled
t_bs = scale_inputs(t_b, t_min, t_max)  # scaled
w_bs = scale_inputs(w_b, w_min, w_max)  # scaled

# initial points
x_i = tf.linspace(x_min, x_max, N_i)[:, None]
t_i = tf.zeros_like(x_i, dtype=DTYPE)
w_i = tf.ones_like(x_i) * w_min
# w_i = tf.linspace(w_min, w_max, N_i)[:, None]
x_is = scale_inputs(x_i, x_min, x_max)  # scaled
t_is = scale_inputs(t_i, t_min, t_max)  # scaled
w_is = scale_inputs(w_i, w_min, w_max)  # scaled

psi_i = tf.cast(psi_init(x_i, w_i, pi), tf.complex128)

# grid for normalization penalty
x_n = tf.linspace(x_min, x_max, N_grid)[:, None]
x_ns = scale_inputs(x_n, x_min, x_max)

# %%
# check shapes and data types
print('x_i')
print(tf.shape(x_is))
print(x_is.dtype)
print(tf.shape(t_is))
print(t_is.dtype)
print(tf.shape(w_is))
print(w_is.dtype)
print(tf.shape(psi_i))
print(psi_i.dtype, '\n')

print('x_b')
print(tf.shape(x_bs))
print(x_bs.dtype)
print(tf.shape(t_bs))
print(t_bs.dtype)
print(tf.shape(w_bs))
print(w_bs.dtype, '\n')

print('x_f')
print(tf.shape(x_fs))
print(x_fs.dtype)
print(tf.shape(t_fs))
print(t_fs.dtype)
print(tf.shape(w_fs))
print(w_fs.dtype, '\n')

print('x_n')
print(tf.shape(x_ns))
print(x_ns.dtype)
# Out:
# x_i
# tf.Tensor([900   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([900   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([900   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([900   1], shape=(2,), dtype=int32)
# <dtype: 'complex128'>
#
# x_b
# tf.Tensor([784   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([784   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([784   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
#
# x_f
# tf.Tensor([4900    1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([4900    1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([4900    1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
#
# x_n
# tf.Tensor([225   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>

# %%
# plot data points

# plotting collocation, boundary, and initial points
plt.scatter(x_f, t_f, alpha=0.5, linewidths=1e-6, label=f'{N_xt*N_xt} collocation points')
plt.scatter(x_b, t_b, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(x_i, t_i, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Unscaled Inputs')
plt.legend(loc='upper right')
plt.show()

plt.scatter(x_fs, t_fs, alpha=0.5, linewidths=1e-6, label=f'{N_xt*N_xt} collocation points')
plt.scatter(x_bs, t_bs, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(x_is, t_is, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Scaled Inputs')
plt.legend(loc='upper right')
plt.show()

plt.scatter(x_fs, w_fs, alpha=0.5, linewidths=1e-6, label=f'{N_xt*N_xt} collocation points')
plt.scatter(x_bs, w_bs, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(x_is, w_is, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('x')
plt.ylabel('$\omega$')
plt.title('Scaled Inputs')
plt.legend(loc='upper right')
plt.show()

plt.scatter(t_fs, w_fs, alpha=0.5, linewidths=1e-6, label=f'{N_xt*N_xt} collocation points')
plt.scatter(t_bs, w_bs, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(t_is, w_is, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('t')
plt.ylabel('$\omega$')
plt.title('Scaled Inputs')
plt.legend(loc='upper right')
plt.show()

# %%
# Fourier feature layer
@tf.keras.utils.register_keras_serializable()
class FourierFeatureLayer(tf.keras.layers.Layer):
    def __init__(self, input_dim, mapping_size=512, scale=10.0, **kwargs):
        super(FourierFeatureLayer, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

    def build(self, input_shape):
        self.B = self.add_weight(name="B",
                                 shape=[self.input_dim, self.mapping_size],
                                 initializer=tf.random_normal_initializer(stddev=self.scale),
                                 trainable=False)
    
    def call(self, x):
        x_proj = tf.matmul(x, self.B)
        return tf.concat([tf.math.sin(x_proj), tf.math.cos(x_proj)], axis=-1)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config
    
# Define the Neural Network
@tf.keras.utils.register_keras_serializable()
class PINN(tf.keras.Model):
    def __init__(self, input_dim=3, mapping_size=512, scale=10.0, **kwargs):
        super(PINN, self).__init__(**kwargs)

        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

        self.fourier = FourierFeatureLayer(input_dim=input_dim, mapping_size=mapping_size, scale=scale)
        initializer = tf.keras.initializers.GlorotNormal()

        self.dense1 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense2 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense3 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense4 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.out = tf.keras.layers.Dense(2, activation='linear', kernel_initializer=initializer) # u_Re, u_Im
        
    def call(self, x):
        x = self.fourier(x)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.out(x)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)
    
# We use Hartree atomic units \hbar = m = 1
# Define the Physics Loss
@tf.function
def pde_residual(model, x, t, w):
    with tf.GradientTape(persistent=True) as tape2:
        tape2.watch([x, t])
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch([x, t])
            xs = scale_inputs(x, x_min, x_max)
            ts = scale_inputs(t, t_min, t_max)
            ws = scale_inputs(w, w_min, w_max)
            X = tf.concat([xs, ts, ws], axis=1)
            # uv = tf.clip_by_value(model(X), -1e2, 1e2) # prevent extreme values
            uv = model(X)
            u, v = uv[:, 0:1], uv[:, 1:2]
        u_x = tape1.gradient(u, x) #, unconnected_gradients='zero')
        v_x = tape1.gradient(v, x) #, unconnected_gradients='zero')
        u_t = tape1.gradient(u, t) #, unconnected_gradients='zero')
        v_t = tape1.gradient(v, t) #, unconnected_gradients='zero')
    u_xx = tape2.gradient(u_x, x) #, unconnected_gradients='zero')
    v_xx = tape2.gradient(v_x, x) #, unconnected_gradients='zero')
    del tape1, tape2

    potential = 0.5 * w**2 * x**2

    f_u = -v_t + 0.5*u_xx - potential*u
    f_v = u_t + 0.5*v_xx - potential*v

    return f_u, f_v

@tf.function
def norm_loss(model, x_ns, N_t):
    t_n = tf.random.uniform((N_t, 1), t_min, t_max, dtype=DTYPE)
    t_ns = scale_inputs(t_n, t_min, t_max)
    w_rand = tf.random.uniform((), w_min, w_max, dtype=DTYPE)
    w_n = tf.ones_like(x_ns) * w_rand
    w_ns = scale_inputs(w_n, w_min, w_max)
    norm_penalty_total = 0.0
    for t_val in tf.unstack(t_ns, axis=0):
        t_in = tf.ones_like(x_ns) * t_val
        X = tf.concat([x_ns, t_in, w_ns], axis=1)
        uv = model(X)
        dx = (x_max - x_min) / tf.cast(tf.shape(x_ns)[0], dtype=DTYPE)
        norm = tf.reduce_sum(tf.math.abs(uv)**2) * dx
        norm_penalty_total += tf.square(norm - 1.0)
    norm_penalty = norm_penalty_total / tf.cast(N_t, dtype=DTYPE)

    return norm_penalty

@tf.function
def loss_fn(model, interior, boundary, initial, norm_grid, omega):
    x_f, t_f = interior
    x_b, t_b = boundary
    x_i, t_i, psi_i = initial
    x_grid, N_t = norm_grid
    w_f, w_b, w_i = omega

    f_u, f_v = pde_residual(model, x_f, t_f, w_f)
    loss_f = tf.reduce_mean(tf.square(f_u) + tf.square(f_v)) # / tf.cast(tf.shape(x_f)[0], dtype=DTYPE)

    uv_b = model(tf.concat([x_b, t_b, w_b], axis=1))
    loss_b = tf.reduce_mean(tf.square(uv_b[:, 0:1]) + tf.square(uv_b[:, 1:2])) # / tf.cast(tf.shape(x_b)[0], dtype=DTYPE)

    uv_i = model(tf.concat([x_i, t_i, w_i], axis=1))
    loss_i = tf.reduce_mean(tf.square(uv_i[:, 0:1] - tf.math.real(psi_i)) +
                            tf.square(uv_i[:, 1:2] - tf.math.imag(psi_i))) # / tf.cast(tf.shape(x_i)[0], dtype=DTYPE)
    
    norm_penalty = norm_loss(model, x_grid, N_t)
    
    return loss_f + loss_b + loss_i + norm_penalty, (loss_f, loss_b, loss_i, norm_penalty)

# %%
# Define the Optimizer
# Learning rate schedule with exponential decay
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=2000,
    decay_rate=0.9,
    staircase=True
)

# ADAM optimizer
optimizer = tf.keras.optimizers.Adam(
    learning_rate=lr_schedule,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    clipnorm=1.0
)

# Training Step Function
@tf.function
def train_step(model, x_f, t_f, x_b, t_b, x_i, t_i, psi_i, x_n, N_t, w_f, w_b, w_i):
    with tf.GradientTape() as tape:
        loss, (lf, lb, li, ln) = loss_fn(model, (x_f, t_f), (x_b, t_b), (x_i, t_i, psi_i), (x_n, N_t), (w_f, w_b, w_i))
        
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss, (lf, lb, li, ln)

# %%
# # Instantiate the Model
pinn = PINN(input_dim=3, mapping_size=512, scale=10.0)

# pinn = tf.keras.models.load_model('best_model_w1_s6.keras', custom_objects={'PINN': PINN})
# print("Model loaded successfully")

# Define the loss threshold
loss_threshold = 1e-10

# Early stopping
early_stopping_patience = 1000
best_loss = float('inf')
patience_counter = 0

# saving loss values
train_loss_results = {
    "total": [],
    "pde": [],
    "boundary": [],
    "initial": [],
    "norm" : []
}

# Start the timer
start_time = time.time()

best_model_path = "best_model_s1.keras"

# Training Loop until loss < loss_threshold
epoch = 0
while True:
    loss, (lf, lb, li, ln) = train_step(pinn, x_f, t_f, x_bs, t_bs, x_is, t_is, psi_i, x_ns, 10, w_f, w_bs, w_is)

    train_loss_results["total"].append(loss.numpy())
    train_loss_results["pde"].append(lf.numpy())
    train_loss_results["boundary"].append(lb.numpy())
    train_loss_results["initial"].append(li.numpy())
    train_loss_results["norm"].append(ln.numpy())

    if epoch % 1000 == 0:
        print(f"Epoch {epoch}: Loss = {loss.numpy().item():.5e} (f = {lf.numpy().item():.3e}, b = {lb.numpy().item():.3e}, i = {li.numpy().item():.3e}, n = {ln.numpy().item():.3e})")
        w_choice = 0.9
        w_test = tf.ones_like(x_is) * w_choice
        w_in = scale_inputs(w_test, w_min, w_max)
        X = tf.concat([x_is, t_is, w_in], axis=1)
        uv = pinn(X)
        u, v = uv[:, 0:1], uv[:, 1:2]
        # test_Re, test_Im = normalization(x_min, x_max, N_i, u, v)
        density = u**2 + v**2

        plt.scatter(x_i, density, label=f'$|\Psi(x,0)|^2$ with $\omega={w_choice}$')
        plt.xlabel('x')
        plt.legend()
        plt.show()
        
    if loss.numpy() < best_loss:
        best_loss = loss.numpy()
        patience_counter = 0
        pinn.save(best_model_path)
        print(f"Best model saved to {best_model_path} at epoch {epoch} with loss {loss.numpy()}")
    else:
        patience_counter += 1

    if patience_counter >= early_stopping_patience:
        print(f"Early stopping at epoch {epoch} as loss did not improve for {early_stopping_patience} epochs.")
        print(f"Training stopped at epoch {epoch} with loss {loss.numpy()}")
        break
    
    if loss.numpy() < loss_threshold:
        print(f"Training stopped at epoch {epoch} as loss reached {loss.numpy()}")
        break

    epoch += 1

# End the timer
end_time = time.time()

# Calculate total execution time
execution_time = end_time - start_time

# Convert to hours, minutes, seconds
execution_time_formatted = str(datetime.timedelta(seconds=int(execution_time)))

print(f"Total training time: {execution_time_formatted}")
        
# Plot the Loss vs. Epochs
plt.plot(train_loss_results["total"], label="Total Loss")
plt.plot(train_loss_results["pde"], label="PDE Loss")
plt.plot(train_loss_results["boundary"], label="Boundary Loss")
plt.plot(train_loss_results["initial"], label="Initial Loss")
plt.plot(train_loss_results["norm"], label="Norm Loss")
plt.yscale("log")
plt.legend()
plt.title("Loss Components During Training")
plt.xlabel("Epoch")
plt.ylabel("Loss (log scale)")
plt.grid(True)
plt.show()

pinn.save('last_trained_s1.keras')
print(f"last model saved")

# Save to CSV
with open("train_loss_results_s1.csv", "w", newline="") as f:
    writer = csv.writer(f)
    
    # Write header
    writer.writerow(["epoch", "total_loss", "pde_loss", "boundary_loss", "initial_loss", "norm_loss"])
    
    # Write data row by row
    for epoch, (total, pde, boundary, initial, norm) in enumerate(zip(
        train_loss_results["total"],
        train_loss_results["pde"],
        train_loss_results["boundary"],
        train_loss_results["initial"],
        train_loss_results["norm"]
    )):
        writer.writerow([epoch, total, pde, boundary, initial, norm])


# # Save original weights
# original_weights = pinn.get_weights()

# # Load the model
# loaded_pinn = tf.keras.models.load_model(best_model_path, custom_objects={'PINN': PINN})

# # Check if the weights match
# loaded_weights = loaded_pinn.get_weights()

# for orig, loaded in zip(original_weights, loaded_weights):
#     if not np.array_equal(orig, loaded):
#         print("Weights do not match after loading!")
#     else:
#         print("Weights match.")
# Out:
# Epoch 0: Loss = 5.44471e+02 (f = 5.351e+02, b = 5.885e-01, i = 5.522e-01, n = 8.221e+00)
# Best model saved to best_model_s1.keras at epoch 0 with loss 544.4705219902559
# Best model saved to best_model_s1.keras at epoch 2 with loss 168.64868964601138
# Best model saved to best_model_s1.keras at epoch 3 with loss 78.90755940570149
# Best model saved to best_model_s1.keras at epoch 4 with loss 52.95536995747199
# Best model saved to best_model_s1.keras at epoch 5 with loss 31.986918934280567
# Best model saved to best_model_s1.keras at epoch 6 with loss 22.812227078774413
# Best model saved to best_model_s1.keras at epoch 7 with loss 16.935034779493428
# Best model saved to best_model_s1.keras at epoch 8 with loss 12.976414318132738
# Best model saved to best_model_s1.keras at epoch 9 with loss 9.523136868445608
# Best model saved to best_model_s1.keras at epoch 10 with loss 8.104785613072584
# Best model saved to best_model_s1.keras at epoch 11 with loss 7.587741381172542
# Best model saved to best_model_s1.keras at epoch 12 with loss 5.94904155153166
# Best model saved to best_model_s1.keras at epoch 13 with loss 5.4030670976561055
# Best model saved to best_model_s1.keras at epoch 14 with loss 4.190722411502066
# Best model saved to best_model_s1.keras at epoch 15 with loss 4.134638741326679
# Best model saved to best_model_s1.keras at epoch 16 with loss 3.4617697428132086
# Best model saved to best_model_s1.keras at epoch 17 with loss 2.933495148385816
# Best model saved to best_model_s1.keras at epoch 18 with loss 2.738386599216904
# Best model saved to best_model_s1.keras at epoch 19 with loss 2.4394227289402877
# Best model saved to best_model_s1.keras at epoch 20 with loss 2.0658863489086454
# Best model saved to best_model_s1.keras at epoch 21 with loss 1.8481224758479768
# Best model saved to best_model_s1.keras at epoch 22 with loss 1.6162847402963736
# Best model saved to best_model_s1.keras at epoch 23 with loss 1.5242311752476165
# Best model saved to best_model_s1.keras at epoch 24 with loss 1.3072468929468484
# Best model saved to best_model_s1.keras at epoch 26 with loss 1.063365930005437
# Best model saved to best_model_s1.keras at epoch 28 with loss 0.9998799507363152
# Best model saved to best_model_s1.keras at epoch 30 with loss 0.998049802349422
# Best model saved to best_model_s1.keras at epoch 33 with loss 0.854018115700279
# Best model saved to best_model_s1.keras at epoch 35 with loss 0.678494745743731
# Best model saved to best_model_s1.keras at epoch 40 with loss 0.5921102510897839
# Best model saved to best_model_s1.keras at epoch 44 with loss 0.589736525787693
# Best model saved to best_model_s1.keras at epoch 47 with loss 0.5889753670810687
# Best model saved to best_model_s1.keras at epoch 49 with loss 0.49022718306973023
# Best model saved to best_model_s1.keras at epoch 51 with loss 0.41098773100063885
# Best model saved to best_model_s1.keras at epoch 53 with loss 0.32995939849520206
# Best model saved to best_model_s1.keras at epoch 81 with loss 0.30285245595755933
# Best model saved to best_model_s1.keras at epoch 83 with loss 0.24022442963305538
# Best model saved to best_model_s1.keras at epoch 85 with loss 0.2247522058196679
# Best model saved to best_model_s1.keras at epoch 106 with loss 0.21634243105585385
# Best model saved to best_model_s1.keras at epoch 108 with loss 0.19293880334129354
# Best model saved to best_model_s1.keras at epoch 131 with loss 0.1736713868555078
# Best model saved to best_model_s1.keras at epoch 133 with loss 0.16334605093635032
# Best model saved to best_model_s1.keras at epoch 135 with loss 0.13320070143594306
# Best model saved to best_model_s1.keras at epoch 174 with loss 0.1315904392135093
# Best model saved to best_model_s1.keras at epoch 176 with loss 0.12986988118376075
# Best model saved to best_model_s1.keras at epoch 180 with loss 0.1195736013103575
# Best model saved to best_model_s1.keras at epoch 214 with loss 0.10727695939957499
# Best model saved to best_model_s1.keras at epoch 216 with loss 0.10694895131852614
# Best model saved to best_model_s1.keras at epoch 224 with loss 0.09918065512238748
# Best model saved to best_model_s1.keras at epoch 250 with loss 0.09783750785022632
# Best model saved to best_model_s1.keras at epoch 280 with loss 0.0975861216329123
# Best model saved to best_model_s1.keras at epoch 282 with loss 0.07773581214415255
# Best model saved to best_model_s1.keras at epoch 321 with loss 0.07257063435197429
# Best model saved to best_model_s1.keras at epoch 351 with loss 0.05920677107755532
# Best model saved to best_model_s1.keras at epoch 355 with loss 0.05260628851097257
# Best model saved to best_model_s1.keras at epoch 425 with loss 0.05010359308334296
# Best model saved to best_model_s1.keras at epoch 456 with loss 0.04805969657303307
# Best model saved to best_model_s1.keras at epoch 469 with loss 0.04106904665911236
# Best model saved to best_model_s1.keras at epoch 477 with loss 0.040244219001605575
# Best model saved to best_model_s1.keras at epoch 478 with loss 0.039974630133321656
# Best model saved to best_model_s1.keras at epoch 482 with loss 0.03623795234569303
# Best model saved to best_model_s1.keras at epoch 533 with loss 0.035753038240815
# Best model saved to best_model_s1.keras at epoch 537 with loss 0.035017659837753595
# Best model saved to best_model_s1.keras at epoch 544 with loss 0.03499203620894289
# Best model saved to best_model_s1.keras at epoch 670 with loss 0.03459277483906854
# Best model saved to best_model_s1.keras at epoch 679 with loss 0.03196449912259279
# Best model saved to best_model_s1.keras at epoch 686 with loss 0.02469714636356875
# Best model saved to best_model_s1.keras at epoch 738 with loss 0.021784617251356237
# Best model saved to best_model_s1.keras at epoch 868 with loss 0.020841187595986993
# Best model saved to best_model_s1.keras at epoch 870 with loss 0.01724958380193934
# Best model saved to best_model_s1.keras at epoch 970 with loss 0.016812389691194814
# Epoch 1000: Loss = 2.72745e-02 (f = 2.085e-02, b = 1.075e-03, i = 3.365e-03, n = 1.982e-03)
# Best model saved to best_model_s1.keras at epoch 1137 with loss 0.013266881282609787
# Best model saved to best_model_s1.keras at epoch 1254 with loss 0.012512812576640346
# Best model saved to best_model_s1.keras at epoch 1258 with loss 0.010457666415655516
# Best model saved to best_model_s1.keras at epoch 1280 with loss 0.01025962847642407
# Best model saved to best_model_s1.keras at epoch 1295 with loss 0.008069862449200589
# Best model saved to best_model_s1.keras at epoch 1446 with loss 0.006743587689381525
# Best model saved to best_model_s1.keras at epoch 1449 with loss 0.006735408035869313
# Best model saved to best_model_s1.keras at epoch 1451 with loss 0.0063488063826082925
# Best model saved to best_model_s1.keras at epoch 1502 with loss 0.0063391707918601095
# Best model saved to best_model_s1.keras at epoch 1503 with loss 0.006112892774109911
# Best model saved to best_model_s1.keras at epoch 1589 with loss 0.005931294805311981
# Best model saved to best_model_s1.keras at epoch 1591 with loss 0.005745017815461359
# Best model saved to best_model_s1.keras at epoch 1623 with loss 0.004402449729033366
# Best model saved to best_model_s1.keras at epoch 1634 with loss 0.004238230778719544
# Best model saved to best_model_s1.keras at epoch 1642 with loss 0.004078870996413749
# Best model saved to best_model_s1.keras at epoch 1643 with loss 0.004060062283021086
# Best model saved to best_model_s1.keras at epoch 1646 with loss 0.0036763642367348063
# Best model saved to best_model_s1.keras at epoch 1648 with loss 0.0036129769127131936
# Best model saved to best_model_s1.keras at epoch 1864 with loss 0.003527336637128372
# Best model saved to best_model_s1.keras at epoch 1940 with loss 0.00335026637032621
# Best model saved to best_model_s1.keras at epoch 1942 with loss 0.0028549807389686675
# Best model saved to best_model_s1.keras at epoch 1951 with loss 0.0027490483040204143
# Epoch 2000: Loss = 3.78284e-03 (f = 2.008e-03, b = 1.344e-04, i = 2.013e-04, n = 1.439e-03)
# Best model saved to best_model_s1.keras at epoch 2063 with loss 0.0024096356642175345
# Best model saved to best_model_s1.keras at epoch 2069 with loss 0.001849055110476307
# Best model saved to best_model_s1.keras at epoch 2070 with loss 0.0015806145968102106
# Best model saved to best_model_s1.keras at epoch 2086 with loss 0.0015228825978511583
# Best model saved to best_model_s1.keras at epoch 2105 with loss 0.0015208449891578571
# Best model saved to best_model_s1.keras at epoch 2106 with loss 0.0014156277726989303
# Best model saved to best_model_s1.keras at epoch 2108 with loss 0.0013924949706397858
# Best model saved to best_model_s1.keras at epoch 2111 with loss 0.0009583734515983046
# Epoch 3000: Loss = 1.05167e-02 (f = 3.960e-03, b = 6.055e-04, i = 7.367e-04, n = 5.215e-03)
# Early stopping at epoch 3111 as loss did not improve for 1000 epochs.
# Training stopped at epoch 3111 with loss 0.008418500457995777
# Total training time: 3:46:18
# last model saved
