# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime

# use float64 for higher precision in PDEs
tf.keras.backend.set_floatx('float64')
DTYPE = tf.float64

# declare inputs
# w_min, w_max = tf.constant(0.75, dtype=DTYPE), tf.constant(2.0, dtype=DTYPE)
w_choice = tf.constant(1.0, dtype=DTYPE)
pi = tf.constant(np.pi, dtype=DTYPE)
x_min, x_max = -pi, pi
t_min, t_max = tf.constant(0.0, dtype=DTYPE), pi/4.0

# generate grid points
def generate_grid_samples(x_min, x_max, t_min, t_max, N_x, N_t):
    x = tf.linspace(x_min, x_max, N_x)
    t = tf.linspace(t_min, t_max, N_t)
    X, T = tf.meshgrid(x, t)
    x_flat = tf.reshape(X, [-1, 1])
    t_flat = tf.reshape(T, [-1, 1])
    return x_flat, t_flat

# scale inputs
@tf.function
def scale_inputs(input, input_min, input_max):
    return 2.0 * (input - input_min) / (input_max - input_min) - 1.0

# # renormalization
# @tf.function
# def normalization(input_min, input_max, N, psi_Re, psi_Im):
#     dx = (input_max - input_min) / tf.cast(N, dtype=DTYPE)
#     norm = tf.math.sqrt(tf.reduce_sum(psi_Re**2 + psi_Im**2) * dx)
#     return (psi_Re/norm), (psi_Im/norm)

# initial condition
@tf.function
def psi_init(x, w, pi):
    u_0 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2)
    u_1 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2) * x * tf.math.sqrt(2.0*w)
    return (1.0/np.sqrt(2.0)) * (u_0 + u_1)

# data generation
N_xt, N_b, N_i, N_grid = 60, 400, 625, 200

# interior points
x_f, t_f = generate_grid_samples(x_min, x_max, t_min, t_max, N_xt, N_xt)
x_fs = scale_inputs(x_f, x_min, x_max)  # scaled
t_fs = scale_inputs(t_f, t_min, t_max)  # scaled

# boundary points
x_b = tf.concat([tf.ones((N_b//2, 1), dtype=DTYPE) * x_min,
                 tf.ones((N_b//2, 1), dtype=DTYPE) * x_max], axis=0)
t_b = tf.linspace(t_min, t_max, N_b//2)[:, None]
t_b = tf.tile(t_b, [2, 1])
x_bs = scale_inputs(x_b, x_min, x_max)  # scaled
t_bs = scale_inputs(t_b, t_min, t_max)  # scaled

# initial points
x_i = tf.linspace(x_min, x_max, N_i)[:, None]
t_i = tf.zeros_like(x_i, dtype=DTYPE)
x_is = scale_inputs(x_i, x_min, x_max)  # scaled
t_is = scale_inputs(t_i, t_min, t_max)  # scaled

psi_i = tf.cast(psi_init(x_i, w_choice, pi), tf.complex128)

# grid for normalization penalty
x_n = tf.linspace(x_min, x_max, N_grid)[:, None]
x_ns = scale_inputs(x_n, x_min, x_max)

# %%
# check shapes and data types
print('x_i')
print(tf.shape(x_is))
print(x_is.dtype)
print(tf.shape(t_is))
print(t_is.dtype, '\n')

print('x_b')
print(tf.shape(x_bs))
print(x_bs.dtype)
print(tf.shape(t_bs))
print(t_bs.dtype, '\n')

print('x_f')
print(tf.shape(x_fs))
print(x_fs.dtype)
print(tf.shape(t_fs))
print(t_fs.dtype, '\n')

print('x_n')
print(tf.shape(x_ns))
print(x_ns.dtype)
# Out:
# x_i
# tf.Tensor([625   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([625   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
#
# x_b
# tf.Tensor([400   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([400   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
#
# x_f
# tf.Tensor([3600    1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
# tf.Tensor([3600    1], shape=(2,), dtype=int32)
# <dtype: 'float64'>
#
# x_n
# tf.Tensor([200   1], shape=(2,), dtype=int32)
# <dtype: 'float64'>

# %%
# plot data points

# plotting collocation, boundary, and initial points
plt.scatter(x_f, t_f, alpha=0.5, linewidths=1e-6, label=f'{N_xt*N_xt} collocation points')
plt.scatter(x_b, t_b, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(x_i, t_i, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Unscaled Inputs')
plt.legend(loc='upper right')
plt.show()

plt.scatter(x_fs, t_fs, alpha=0.5, linewidths=1e-6, label=f'{N_xt*N_xt} collocation points')
plt.scatter(x_bs, t_bs, alpha=0.5, linewidths=1e-6, label=f'{N_b} boundary points')
plt.scatter(x_is, t_is, alpha=0.5, linewidths=1e-6, label=f'{N_i} initial points')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Scaled Inputs')
plt.legend(loc='upper right')
plt.show()

# %%
# Fourier feature layer
@tf.keras.utils.register_keras_serializable()
class FourierFeatureLayer(tf.keras.layers.Layer):
    def __init__(self, input_dim, mapping_size=512, scale=10.0, **kwargs):
        super(FourierFeatureLayer, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

    def build(self, input_shape):
        self.B = self.add_weight(name="B",
                                 shape=[self.input_dim, self.mapping_size],
                                 initializer=tf.random_normal_initializer(stddev=self.scale),
                                 trainable=False)
    
    def call(self, x):
        x_proj = tf.matmul(x, self.B)
        return tf.concat([tf.math.sin(x_proj), tf.math.cos(x_proj)], axis=-1)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config
    
# Define the Neural Network
@tf.keras.utils.register_keras_serializable()
class PINN(tf.keras.Model):
    def __init__(self, input_dim=2, mapping_size=512, scale=10.0, **kwargs):
        super(PINN, self).__init__(**kwargs)

        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

        self.fourier = FourierFeatureLayer(input_dim=input_dim, mapping_size=mapping_size, scale=scale)
        initializer = tf.keras.initializers.GlorotNormal()

        self.dense1 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense2 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense3 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense4 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.out = tf.keras.layers.Dense(2, activation='linear', kernel_initializer=initializer) # u_Re, u_Im
        
    def call(self, x):
        x = self.fourier(x)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.out(x)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)
    
# We use Hartree atomic units \hbar = m = 1
# Define the Physics Loss
@tf.function
def pde_residual(model, x, t):
    with tf.GradientTape(persistent=True) as tape2:
        tape2.watch([x, t])
        with tf.GradientTape(persistent=True) as tape1:
            tape1.watch([x, t])
            xs = scale_inputs(x, x_min, x_max)
            ts = scale_inputs(t, t_min, t_max)
            X = tf.concat([xs, ts], axis=1)
            # uv = tf.clip_by_value(model(X), -1e2, 1e2) # prevent extreme values
            uv = model(X)
            u, v = uv[:, 0:1], uv[:, 1:2]
        u_x = tape1.gradient(u, x) #, unconnected_gradients='zero')
        v_x = tape1.gradient(v, x) #, unconnected_gradients='zero')
        u_t = tape1.gradient(u, t) #, unconnected_gradients='zero')
        v_t = tape1.gradient(v, t) #, unconnected_gradients='zero')
    u_xx = tape2.gradient(u_x, x) #, unconnected_gradients='zero')
    v_xx = tape2.gradient(v_x, x) #, unconnected_gradients='zero')
    del tape1, tape2

    potential = 0.5 * w_choice**2 * x**2

    f_u = -v_t + 0.5*u_xx - potential*u
    f_v = u_t + 0.5*v_xx - potential*v

    return f_u, f_v

@tf.function
def norm_loss(model, x_ns, N_t):
    t_n = tf.random.uniform((N_t, 1), t_min, t_max, dtype=DTYPE)
    t_ns = scale_inputs(t_n, t_min, t_max)
    norm_penalty_total = 0.0
    for t_val in tf.unstack(t_ns, axis=0):
        t_in = tf.ones_like(x_ns) * t_val
        X = tf.concat([x_ns, t_in], axis=1)
        uv = model(X)
        dx = (x_max - x_min) / tf.cast(tf.shape(x_ns)[0], dtype=DTYPE)
        norm = tf.reduce_sum(tf.math.abs(uv)**2) * dx
        norm_penalty_total += tf.square(norm - 1.0)
    norm_penalty = norm_penalty_total / tf.cast(N_t, dtype=DTYPE)

    return norm_penalty

@tf.function
def loss_fn(model, interior, boundary, initial, norm_grid):
    x_f, t_f = interior
    x_b, t_b = boundary
    x_i, t_i, psi_i = initial
    x_grid, N_t = norm_grid

    f_u, f_v = pde_residual(model, x_f, t_f)
    loss_f = tf.reduce_mean(tf.square(f_u) + tf.square(f_v)) # / tf.cast(tf.shape(x_f)[0], dtype=DTYPE)

    uv_b = model(tf.concat([x_b, t_b], axis=1))
    loss_b = tf.reduce_mean(tf.square(uv_b[:, 0:1]) + tf.square(uv_b[:, 1:2])) # / tf.cast(tf.shape(x_b)[0], dtype=DTYPE)

    uv_i = model(tf.concat([x_i, t_i], axis=1))
    loss_i = tf.reduce_mean(tf.square(uv_i[:, 0:1] - tf.math.real(psi_i)) +
                            tf.square(uv_i[:, 1:2] - tf.math.imag(psi_i))) # / tf.cast(tf.shape(x_i)[0], dtype=DTYPE)
    
    norm_penalty = norm_loss(model, x_grid, N_t)
    
    return loss_f + loss_b + loss_i + norm_penalty, (loss_f, loss_b, loss_i, norm_penalty)

# %%
# Define the Optimizer
# Learning rate schedule with exponential decay
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=2000,
    decay_rate=0.9,
    staircase=True
)

# ADAM optimizer
optimizer = tf.keras.optimizers.Adam(
    learning_rate=lr_schedule,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    clipnorm=1.0
)

# Training Step Function
@tf.function
def train_step(model, x_f, t_f, x_b, t_b, x_i, t_i, psi_i, x_n, N_t):
    with tf.GradientTape() as tape:
        loss, (lf, lb, li, ln) = loss_fn(model, (x_f, t_f), (x_b, t_b), (x_i, t_i, psi_i), (x_n, N_t))
        
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss, (lf, lb, li, ln)

# %%
# # Instantiate the Model
pinn = PINN(input_dim=2, mapping_size=512, scale=10.0)

# pinn = tf.keras.models.load_model('best_model_w1p1.keras', custom_objects={'PINN': PINN})
# print("Model loaded successfully")

# Define the loss threshold
loss_threshold = 1e-10

# Early stopping
early_stopping_patience = 1000
best_loss = float('inf')
patience_counter = 0

# saving loss values
train_loss_results = {
    "total": [],
    "pde": [],
    "boundary": [],
    "initial": [],
    "norm" : []
}

# Start the timer
start_time = time.time()

best_model_path = "best_model_w1_s1.keras"

# Training Loop until loss < loss_threshold
epoch = 0
while True:
    loss, (lf, lb, li, ln) = train_step(pinn, x_f, t_f, x_bs, t_bs, x_is, t_is, psi_i, x_ns, 10)

    train_loss_results["total"].append(loss.numpy())
    train_loss_results["pde"].append(lf.numpy())
    train_loss_results["boundary"].append(lb.numpy())
    train_loss_results["initial"].append(li.numpy())
    train_loss_results["norm"].append(ln.numpy())

    if epoch % 500 == 0:
        print(f"Epoch {epoch}: Loss = {loss.numpy().item():.5e} (f = {lf.numpy().item():.3e}, b = {lb.numpy().item():.3e}, i = {li.numpy().item():.3e}, n = {ln.numpy().item():.3e})")

        X = tf.concat([x_is, t_is], axis=1)
        uv = pinn(X)
        u, v = uv[:, 0:1], uv[:, 1:2]
        # test_Re, test_Im = normalization(x_min, x_max, N_i, u, v)
        density = u**2 + v**2

        plt.scatter(x_i, density, label=r'$|\Psi(x,0)|^2$ with \omega=1.0')
        plt.xlabel('x')
        plt.legend()
        plt.show()
        
    if loss.numpy() < best_loss:
        best_loss = loss.numpy()
        patience_counter = 0
        pinn.save(best_model_path)
        print(f"Best model saved to {best_model_path} at epoch {epoch} with loss {loss.numpy()}")
    else:
        patience_counter += 1

    if patience_counter >= early_stopping_patience:
        print(f"Early stopping at epoch {epoch} as loss did not improve for {early_stopping_patience} epochs.")
        print(f"Training stopped at epoch {epoch} with loss {loss.numpy()}")
        break
    
    if loss.numpy() < loss_threshold:
        print(f"Training stopped at epoch {epoch} as loss reached {loss.numpy()}")
        break

    epoch += 1

# End the timer
end_time = time.time()

# Calculate total execution time
execution_time = end_time - start_time

# Convert to hours, minutes, seconds
execution_time_formatted = str(datetime.timedelta(seconds=int(execution_time)))

print(f"Total training time: {execution_time_formatted}")
        
# Plot the Loss vs. Epochs
plt.plot(train_loss_results["total"], label="Total Loss")
plt.plot(train_loss_results["pde"], label="PDE Loss")
plt.plot(train_loss_results["boundary"], label="Boundary Loss")
plt.plot(train_loss_results["initial"], label="Initial Loss")
plt.plot(train_loss_results["norm"], label="Norm Loss")
plt.yscale("log")
plt.legend()
plt.title("Loss Components During Training")
plt.xlabel("Epoch")
plt.ylabel("Loss (log scale)")
plt.grid(True)
plt.show()

# # Save original weights
# original_weights = pinn.get_weights()

# # Load the model
# loaded_pinn = tf.keras.models.load_model(best_model_path, custom_objects={'PINN': PINN})

# # Check if the weights match
# loaded_weights = loaded_pinn.get_weights()

# for orig, loaded in zip(original_weights, loaded_weights):
#     if not np.array_equal(orig, loaded):
#         print("Weights do not match after loading!")
#     else:
#         print("Weights match.")
# Out:
# Epoch 0: Loss = 5.75624e+02 (f = 5.708e+02, b = 4.780e-01, i = 6.780e-01, n = 3.664e+00)
# Best model saved to best_model_w1_s1.keras at epoch 0 with loss 575.623650674334
# Best model saved to best_model_w1_s1.keras at epoch 2 with loss 190.235763561611
# Best model saved to best_model_w1_s1.keras at epoch 3 with loss 88.19685079010712
# Best model saved to best_model_w1_s1.keras at epoch 4 with loss 52.7754891708282
# Best model saved to best_model_w1_s1.keras at epoch 5 with loss 30.99943451981634
# Best model saved to best_model_w1_s1.keras at epoch 6 with loss 24.363606104845054
# Best model saved to best_model_w1_s1.keras at epoch 7 with loss 19.44260935506309
# Best model saved to best_model_w1_s1.keras at epoch 8 with loss 15.083129195884451
# Best model saved to best_model_w1_s1.keras at epoch 9 with loss 10.916249452942594
# Best model saved to best_model_w1_s1.keras at epoch 10 with loss 9.275564260748364
# Best model saved to best_model_w1_s1.keras at epoch 11 with loss 8.19965815073497
# Best model saved to best_model_w1_s1.keras at epoch 12 with loss 6.455185889064854
# Best model saved to best_model_w1_s1.keras at epoch 13 with loss 5.773810565422336
# Best model saved to best_model_w1_s1.keras at epoch 14 with loss 4.760862593399638
# Best model saved to best_model_w1_s1.keras at epoch 15 with loss 4.5678165253843845
# Best model saved to best_model_w1_s1.keras at epoch 16 with loss 3.792763510502387
# Best model saved to best_model_w1_s1.keras at epoch 17 with loss 3.6950679802168724
# Best model saved to best_model_w1_s1.keras at epoch 18 with loss 3.3127864553689492
# Best model saved to best_model_w1_s1.keras at epoch 19 with loss 2.862341391553486
# Best model saved to best_model_w1_s1.keras at epoch 20 with loss 2.440641411405488
# Best model saved to best_model_w1_s1.keras at epoch 21 with loss 2.197423718709477
# Best model saved to best_model_w1_s1.keras at epoch 22 with loss 2.0922035101408896
# Best model saved to best_model_w1_s1.keras at epoch 23 with loss 1.9300091316018297
# Best model saved to best_model_w1_s1.keras at epoch 24 with loss 1.7399938579881047
# Best model saved to best_model_w1_s1.keras at epoch 25 with loss 1.5740990625649767
# Best model saved to best_model_w1_s1.keras at epoch 26 with loss 1.2186034068593856
# Best model saved to best_model_w1_s1.keras at epoch 28 with loss 1.110517862765358
# Best model saved to best_model_w1_s1.keras at epoch 30 with loss 0.9306794329952283
# Best model saved to best_model_w1_s1.keras at epoch 35 with loss 0.8682664157995328
# Best model saved to best_model_w1_s1.keras at epoch 37 with loss 0.6262373755108559
# Best model saved to best_model_w1_s1.keras at epoch 43 with loss 0.6125736448570636
# Best model saved to best_model_w1_s1.keras at epoch 50 with loss 0.581087111713065
# Best model saved to best_model_w1_s1.keras at epoch 53 with loss 0.5171565732649291
# Best model saved to best_model_w1_s1.keras at epoch 56 with loss 0.4515831253209166
# Best model saved to best_model_w1_s1.keras at epoch 58 with loss 0.41434919087830147
# Best model saved to best_model_w1_s1.keras at epoch 60 with loss 0.3724722620572148
# Best model saved to best_model_w1_s1.keras at epoch 62 with loss 0.30404798060568816
# Best model saved to best_model_w1_s1.keras at epoch 85 with loss 0.3004842889130041
# Best model saved to best_model_w1_s1.keras at epoch 99 with loss 0.29086029107008543
# Best model saved to best_model_w1_s1.keras at epoch 103 with loss 0.2774770279284324
# Best model saved to best_model_w1_s1.keras at epoch 105 with loss 0.2420121321729237
# Best model saved to best_model_w1_s1.keras at epoch 107 with loss 0.21464803129137386
# Best model saved to best_model_w1_s1.keras at epoch 127 with loss 0.19265567431540753
# Best model saved to best_model_w1_s1.keras at epoch 136 with loss 0.18147724014999594
# Best model saved to best_model_w1_s1.keras at epoch 138 with loss 0.17847741607708922
# Best model saved to best_model_w1_s1.keras at epoch 140 with loss 0.16324301275668165
# Best model saved to best_model_w1_s1.keras at epoch 150 with loss 0.14364622341017877
# Best model saved to best_model_w1_s1.keras at epoch 154 with loss 0.12847567621505304
# Best model saved to best_model_w1_s1.keras at epoch 200 with loss 0.121997794732598
# Best model saved to best_model_w1_s1.keras at epoch 202 with loss 0.11721841942972543
# Best model saved to best_model_w1_s1.keras at epoch 204 with loss 0.09927496255973285
# Best model saved to best_model_w1_s1.keras at epoch 237 with loss 0.09079642809515957
# Best model saved to best_model_w1_s1.keras at epoch 251 with loss 0.0704747102264955
# Best model saved to best_model_w1_s1.keras at epoch 270 with loss 0.06929895681988123
# Best model saved to best_model_w1_s1.keras at epoch 280 with loss 0.06099897381928488
# Best model saved to best_model_w1_s1.keras at epoch 296 with loss 0.06010666003857856
# Best model saved to best_model_w1_s1.keras at epoch 300 with loss 0.059142541556310026
# Best model saved to best_model_w1_s1.keras at epoch 312 with loss 0.05885877535980076
# Best model saved to best_model_w1_s1.keras at epoch 332 with loss 0.05611771909394786
# Best model saved to best_model_w1_s1.keras at epoch 345 with loss 0.055098475786722376
# Best model saved to best_model_w1_s1.keras at epoch 347 with loss 0.04379231288788128
# Best model saved to best_model_w1_s1.keras at epoch 374 with loss 0.039981188029291244
# Best model saved to best_model_w1_s1.keras at epoch 378 with loss 0.034728999912065885
# Best model saved to best_model_w1_s1.keras at epoch 420 with loss 0.031276917534970715
# Best model saved to best_model_w1_s1.keras at epoch 466 with loss 0.03086513484771139
# Best model saved to best_model_w1_s1.keras at epoch 468 with loss 0.026337700866154397
# Best model saved to best_model_w1_s1.keras at epoch 489 with loss 0.02453599709628046
# Best model saved to best_model_w1_s1.keras at epoch 491 with loss 0.022601358107351928
# Epoch 500: Loss = 4.33293e-02 (f = 2.607e-02, b = 5.107e-04, i = 1.908e-03, n = 1.484e-02)
# Best model saved to best_model_w1_s1.keras at epoch 567 with loss 0.02172352369004651
# Best model saved to best_model_w1_s1.keras at epoch 569 with loss 0.01898509726388174
# Best model saved to best_model_w1_s1.keras at epoch 670 with loss 0.01833078529331889
# Best model saved to best_model_w1_s1.keras at epoch 674 with loss 0.017769248413791346
# Best model saved to best_model_w1_s1.keras at epoch 680 with loss 0.01629569537137754
# Best model saved to best_model_w1_s1.keras at epoch 714 with loss 0.01609054859173873
# Best model saved to best_model_w1_s1.keras at epoch 716 with loss 0.014902743351763306
# Best model saved to best_model_w1_s1.keras at epoch 722 with loss 0.01365507104915991
# Best model saved to best_model_w1_s1.keras at epoch 768 with loss 0.01088928162287241
# Best model saved to best_model_w1_s1.keras at epoch 806 with loss 0.010602440073055892
# Best model saved to best_model_w1_s1.keras at epoch 826 with loss 0.010566947228020243
# Best model saved to best_model_w1_s1.keras at epoch 869 with loss 0.010064981753646451
# Best model saved to best_model_w1_s1.keras at epoch 937 with loss 0.00798103448715392
# Epoch 1000: Loss = 7.96956e-03 (f = 7.508e-03, b = 1.440e-04, i = 1.443e-04, n = 1.731e-04)
# Best model saved to best_model_w1_s1.keras at epoch 1000 with loss 0.007969557891937784
# Best model saved to best_model_w1_s1.keras at epoch 1002 with loss 0.007664728068684009
# Best model saved to best_model_w1_s1.keras at epoch 1039 with loss 0.0071458415098547634
# Best model saved to best_model_w1_s1.keras at epoch 1041 with loss 0.0067299837091416344
# Best model saved to best_model_w1_s1.keras at epoch 1098 with loss 0.006501610407511603
# Best model saved to best_model_w1_s1.keras at epoch 1099 with loss 0.005739452660586527
# Best model saved to best_model_w1_s1.keras at epoch 1100 with loss 0.005345878690003664
# Best model saved to best_model_w1_s1.keras at epoch 1101 with loss 0.005282959746742157
# Best model saved to best_model_w1_s1.keras at epoch 1107 with loss 0.004540504922002373
# Best model saved to best_model_w1_s1.keras at epoch 1108 with loss 0.0029952590212616384
# Best model saved to best_model_w1_s1.keras at epoch 1112 with loss 0.0028609213196712814
# Best model saved to best_model_w1_s1.keras at epoch 1147 with loss 0.0020085283114371494
# Best model saved to best_model_w1_s1.keras at epoch 1148 with loss 0.001800618464034949
# Best model saved to best_model_w1_s1.keras at epoch 1186 with loss 0.0017421267066584725
# Best model saved to best_model_w1_s1.keras at epoch 1187 with loss 0.0015304888333624058
# Best model saved to best_model_w1_s1.keras at epoch 1191 with loss 0.0013424635800472129
# Best model saved to best_model_w1_s1.keras at epoch 1209 with loss 0.0012430712408496073
# Best model saved to best_model_w1_s1.keras at epoch 1211 with loss 0.0012417613929449503
# Best model saved to best_model_w1_s1.keras at epoch 1212 with loss 0.0009369987390028186
# Best model saved to best_model_w1_s1.keras at epoch 1213 with loss 0.0007599650833766152
# Best model saved to best_model_w1_s1.keras at epoch 1217 with loss 0.0005164328551957233
# Best model saved to best_model_w1_s1.keras at epoch 1218 with loss 0.000462602732782098
# Best model saved to best_model_w1_s1.keras at epoch 1220 with loss 0.00045972313219568326
# Best model saved to best_model_w1_s1.keras at epoch 1221 with loss 0.00042178533478467566
# Best model saved to best_model_w1_s1.keras at epoch 1222 with loss 0.00039616301390935
# Best model saved to best_model_w1_s1.keras at epoch 1223 with loss 0.00039458379442219827
# Best model saved to best_model_w1_s1.keras at epoch 1224 with loss 0.00036593126527924904
# Best model saved to best_model_w1_s1.keras at epoch 1225 with loss 0.0003617496959706887
# Best model saved to best_model_w1_s1.keras at epoch 1227 with loss 0.0003379615297420675
# Best model saved to best_model_w1_s1.keras at epoch 1228 with loss 0.0002563742000995179
# Best model saved to best_model_w1_s1.keras at epoch 1246 with loss 0.00024179084971677727
# Best model saved to best_model_w1_s1.keras at epoch 1251 with loss 0.00019844583909681872
# Best model saved to best_model_w1_s1.keras at epoch 1255 with loss 0.00014734108115303194
# Best model saved to best_model_w1_s1.keras at epoch 1258 with loss 0.0001201305062335218
# Best model saved to best_model_w1_s1.keras at epoch 1259 with loss 0.0001009751378246885
# Best model saved to best_model_w1_s1.keras at epoch 1263 with loss 8.517539929824801e-05
# Best model saved to best_model_w1_s1.keras at epoch 1264 with loss 8.042404862634248e-05
# Best model saved to best_model_w1_s1.keras at epoch 1265 with loss 7.79056518174479e-05
# Best model saved to best_model_w1_s1.keras at epoch 1278 with loss 7.594035169440105e-05
# Best model saved to best_model_w1_s1.keras at epoch 1280 with loss 6.752447378283803e-05
# Best model saved to best_model_w1_s1.keras at epoch 1281 with loss 6.216015833877879e-05
# Best model saved to best_model_w1_s1.keras at epoch 1283 with loss 5.53168778728926e-05
# Best model saved to best_model_w1_s1.keras at epoch 1284 with loss 5.3668224942671174e-05
# Best model saved to best_model_w1_s1.keras at epoch 1285 with loss 4.595159782474157e-05
# Best model saved to best_model_w1_s1.keras at epoch 1286 with loss 4.163670087820101e-05
# Best model saved to best_model_w1_s1.keras at epoch 1289 with loss 3.831145379353541e-05
# Best model saved to best_model_w1_s1.keras at epoch 1290 with loss 3.6979773856812004e-05
# Best model saved to best_model_w1_s1.keras at epoch 1294 with loss 3.0826119357736415e-05
# Best model saved to best_model_w1_s1.keras at epoch 1295 with loss 2.9693040464672373e-05
# Best model saved to best_model_w1_s1.keras at epoch 1298 with loss 2.745704474757198e-05
# Best model saved to best_model_w1_s1.keras at epoch 1299 with loss 2.5248916522102857e-05
# Epoch 1500: Loss = 5.29832e-03 (f = 1.013e-03, b = 6.934e-05, i = 3.712e-04, n = 3.845e-03)
# Best model saved to best_model_w1_s1.keras at epoch 1768 with loss 2.500690473742076e-05
# Best model saved to best_model_w1_s1.keras at epoch 1770 with loss 2.3052613654303914e-05
# Best model saved to best_model_w1_s1.keras at epoch 1774 with loss 2.245238602316544e-05
# Best model saved to best_model_w1_s1.keras at epoch 1782 with loss 2.171096590219826e-05
# Best model saved to best_model_w1_s1.keras at epoch 1783 with loss 2.0944730724526655e-05
# Best model saved to best_model_w1_s1.keras at epoch 1827 with loss 1.862709768628599e-05
# Best model saved to best_model_w1_s1.keras at epoch 1829 with loss 1.7559269903524056e-05
# Best model saved to best_model_w1_s1.keras at epoch 1830 with loss 1.6219161935831144e-05
# Best model saved to best_model_w1_s1.keras at epoch 1831 with loss 1.5884930210891163e-05
# Best model saved to best_model_w1_s1.keras at epoch 1832 with loss 1.5000999100282804e-05
# Best model saved to best_model_w1_s1.keras at epoch 1833 with loss 1.4394593842153455e-05
# Best model saved to best_model_w1_s1.keras at epoch 1836 with loss 1.333731688220613e-05
# Best model saved to best_model_w1_s1.keras at epoch 1837 with loss 1.2460806191191617e-05
# Epoch 2000: Loss = 5.53110e-03 (f = 4.869e-03, b = 1.872e-05, i = 1.289e-04, n = 5.141e-04)
# Best model saved to best_model_w1_s1.keras at epoch 2216 with loss 1.2447427620714015e-05
# Best model saved to best_model_w1_s1.keras at epoch 2217 with loss 1.2361877831733252e-05
# Best model saved to best_model_w1_s1.keras at epoch 2223 with loss 1.178225409220084e-05
# Best model saved to best_model_w1_s1.keras at epoch 2243 with loss 1.157514752487225e-05
# Best model saved to best_model_w1_s1.keras at epoch 2245 with loss 1.106960990276833e-05
# Best model saved to best_model_w1_s1.keras at epoch 2246 with loss 1.0216058497515525e-05
# Best model saved to best_model_w1_s1.keras at epoch 2251 with loss 1.0056002584321146e-05
# Best model saved to best_model_w1_s1.keras at epoch 2252 with loss 9.785177849518653e-06
# Best model saved to best_model_w1_s1.keras at epoch 2253 with loss 9.125206639505738e-06
# Best model saved to best_model_w1_s1.keras at epoch 2256 with loss 9.083103000901737e-06
# Best model saved to best_model_w1_s1.keras at epoch 2257 with loss 8.938634349987143e-06
# Best model saved to best_model_w1_s1.keras at epoch 2290 with loss 8.734829511169997e-06
# Best model saved to best_model_w1_s1.keras at epoch 2295 with loss 8.419371434795166e-06
# Epoch 2500: Loss = 3.15954e-02 (f = 2.933e-02, b = 8.404e-04, i = 1.084e-03, n = 3.408e-04)
# Epoch 3000: Loss = 5.48554e-05 (f = 4.658e-05, b = 2.535e-06, i = 5.022e-06, n = 7.153e-07)
# Early stopping at epoch 3295 as loss did not improve for 1000 epochs.
# Training stopped at epoch 3295 with loss 0.0008668565636582771
# Total training time: 3:00:09

# %%
pinn.save('last_trained_w1_s1.keras')
print(f"last model saved")
# Out:
# last model saved

# %%
import csv

# Save to CSV
with open("train_loss_results_w1_s1.csv", "w", newline="") as f:
    writer = csv.writer(f)
    
    # Write header
    writer.writerow(["epoch", "total_loss", "pde_loss", "boundary_loss", "initial_loss", "norm_loss"])
    
    # Write data row by row
    for epoch, (total, pde, boundary, initial, norm) in enumerate(zip(
        train_loss_results["total"],
        train_loss_results["pde"],
        train_loss_results["boundary"],
        train_loss_results["initial"],
        train_loss_results["norm"]
    )):
        writer.writerow([epoch, total, pde, boundary, initial, norm])

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime

# use float64 for higher precision in PDEs
tf.keras.backend.set_floatx('float64')
DTYPE = tf.float64

# declare inputs
# w_min, w_max = tf.constant(0.75, dtype=DTYPE), tf.constant(2.0, dtype=DTYPE)
w_choice = tf.constant(1.0, dtype=DTYPE)
pi = tf.constant(np.pi, dtype=DTYPE)
x_min, x_max = -pi, pi
t_min, t_max = tf.constant(0.0, dtype=DTYPE), pi/4.0

# scale inputs
@tf.function
def scale_inputs(input, input_min, input_max):
    return 2.0 * (input - input_min) / (input_max - input_min) - 1.0

# # renormalization
# @tf.function
# def normalization(input_min, input_max, N, psi_Re, psi_Im):
#     dx = (input_max - input_min) / tf.cast(N, dtype=DTYPE)
#     norm = tf.math.sqrt(tf.reduce_sum(psi_Re**2 + psi_Im**2) * dx)
#     return (psi_Re/norm), (psi_Im/norm)

# initial condition
@tf.function
def psi_init(x, w, pi):
    u_0 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2)
    u_1 = (w/pi)**0.25 * tf.math.exp(-0.5*w*x**2) * x * tf.math.sqrt(2.0*w)
    return (1.0/np.sqrt(2.0)) * (u_0 + u_1)

# data generation
N_f, N_b, N_i, N_grid = 5000, 1000, 1000, 200

# interior points
x_f = tf.random.uniform((N_f, 1), x_min, x_max, dtype=DTYPE)
t_f = tf.random.uniform((N_f, 1), t_min, t_max, dtype=DTYPE)
x_fs = scale_inputs(x_f, x_min, x_max)  # scaled
t_fs = scale_inputs(t_f, t_min, t_max)  # scaled

# boundary points
x_b = tf.concat([tf.ones((N_b//2, 1), dtype=DTYPE) * x_min,
                 tf.ones((N_b//2, 1), dtype=DTYPE) * x_max], axis=0)
t_b = tf.random.uniform((N_b, 1), t_min, t_max, dtype=DTYPE)
x_bs = scale_inputs(x_b, x_min, x_max)  # scaled
t_bs = scale_inputs(t_b, t_min, t_max)  # scaled

# initial points
x_i = tf.random.uniform((N_i, 1), x_min, x_max, dtype=DTYPE)
t_i = tf.zeros_like(x_i, dtype=DTYPE)
x_is = scale_inputs(x_i, x_min, x_max)  # scaled
t_is = scale_inputs(t_i, t_min, t_max)  # scaled

psi_i = tf.cast(psi_init(x_i, w_choice, pi), tf.complex128)

# grid for normalization penalty
x_n = tf.linspace(x_min, x_max, N_grid)[:, None]
x_ns = scale_inputs(x_n, x_min, x_max)

# verify normalization
dx_i = (x_max - x_min) / N_i
norm_check = tf.reduce_sum(tf.math.abs(psi_i)**2) * dx_i
print(f'Normalization check for the initial condition: $|\Psi(x,0)|**2={norm_check}$')

# Fourier feature layer
@tf.keras.utils.register_keras_serializable()
class FourierFeatureLayer(tf.keras.layers.Layer):
    def __init__(self, input_dim, mapping_size=512, scale=10.0, **kwargs):
        super(FourierFeatureLayer, self).__init__(**kwargs)
        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

    def build(self, input_shape):
        self.B = self.add_weight(name="B",
                                 shape=[self.input_dim, self.mapping_size],
                                 initializer=tf.random_normal_initializer(stddev=self.scale),
                                 trainable=False)
    
    def call(self, x):
        x_proj = tf.matmul(x, self.B)
        return tf.concat([tf.math.sin(x_proj), tf.math.cos(x_proj)], axis=-1)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config
    
# Define the Neural Network
@tf.keras.utils.register_keras_serializable()
class PINN(tf.keras.Model):
    def __init__(self, input_dim=2, mapping_size=512, scale=10.0, **kwargs):
        super(PINN, self).__init__(**kwargs)

        self.input_dim = input_dim
        self.mapping_size = mapping_size
        self.scale = scale

        self.fourier = FourierFeatureLayer(input_dim=input_dim, mapping_size=mapping_size, scale=scale)
        initializer = tf.keras.initializers.GlorotNormal()

        self.dense1 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense2 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense3 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.dense4 = tf.keras.layers.Dense(512, activation='tanh', kernel_initializer=initializer)
        self.out = tf.keras.layers.Dense(2, activation='linear', kernel_initializer=initializer) # u_Re, u_Im
        
    def call(self, x):
        x = self.fourier(x)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.out(x)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "input_dim": self.input_dim,
            "mapping_size": self.mapping_size,
            "scale": self.scale
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)
    
# Load the model
loaded_model = tf.keras.models.load_model('best_model_w1_s1.keras', custom_objects={'PINN': PINN})
print("Model loaded successfully")

loaded_model.summary()

################## Plot: Contour Plot ###############################

# Contour Plot
N = 100
x_plot = np.linspace(x_min, x_max, N)[:,None]
t_plot = np.linspace(t_min, t_max, N)[:,None]
x_plot_scaled = scale_inputs(x_plot, x_min, x_max)
t_plot_scaled = scale_inputs(t_plot, t_min, t_max)
X_grid, T_grid = np.meshgrid(x_plot, t_plot)  # t and x grid

x_plot_in = tf.convert_to_tensor(x_plot_scaled, dtype=DTYPE)
t_plot_in = tf.convert_to_tensor(t_plot_scaled, dtype=DTYPE)

density_interior = []

count = 0
for t_val in tf.unstack(t_plot_in, axis=0):
    t_in = tf.ones_like(x_plot_in) * t_val
    input = tf.concat([x_plot_in, t_in], axis=1)
    uv = loaded_model(input)
    u, v = uv[:, 0], uv[:, 1]
    density = u**2 + v**2
    # psi_Re, psi_Im = normalization(x_min, x_max, N, u, v)
    # density = psi_Re**2 + psi_Im**2
    density_interior.append(density)

# plt.figure(figsize=(8, 5))
contour = plt.contourf(X_grid, T_grid, density_interior, levels=100, cmap="viridis")
plt.colorbar(contour, label=r'$|\Psi(x,t)|^2$')
plt.xlabel(r'$x$')
plt.ylabel(r'$t$')
plt.title(f'Predicted $|\Psi(x,t)|^2$ with $\omega={w_choice}$')
plt.tight_layout()
plt.show()

################## Plot: Initial Condition ###############################

X = tf.concat([x_is, t_is], axis=1)
uv = loaded_model(X)
u, v = uv[:, 0:1], uv[:, 1:2]
# psi_Re, psi_Im = normalization(x_min, x_max, N_i, u, v)
# density_initial = psi_Re**2 + psi_Im**2

plt.scatter(x_i, u**2 + v**2, label=r'Predicted $|\Psi(x,0)|^2$')
# plt.scatter(x_i, density_initial, label=r'Normalized Predicted $|\Psi(x,0)|^2$')
plt.scatter(x_i, tf.math.abs(psi_i)**2, label=r'Expected $|\Psi(x,0)|^2$')
plt.xlabel('x')
plt.legend()
plt.show()

################## Plot: Boundary Condition ###############################

X = tf.concat([x_bs, t_bs], axis=1)
uv = loaded_model(X)
u, v = uv[:, 0:1], uv[:, 1:2]
# psi_Re, psi_Im = normalization(x_min, x_max, N_b, u, v)
# density_boundary = psi_Re**2 + psi_Im**2

plt.scatter(t_b, u**2 + v**2, label=r'Predicted $|\Psi(x_b,t)|^2$')
# plt.scatter(t_b, density_boundary, label=r'Normalized Predicted $|\Psi(x_b,t)|^2$')
plt.xlabel('t')
plt.legend()
plt.show()
# Out:
# Normalization check for the initial condition: $|\Psi(x,0)|**2=0.9987959430516256$
# WARNING:tensorflow:From c:\Users\HP\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Model loaded successfully
# Model: "pinn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fourier_feature_layer_1         │ ?                      │         1,024 │
# │ (FourierFeatureLayer)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (3600, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (3600, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (3600, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (3600, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (3600, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,314,818 (10.03 MB)
#  Trainable params: 1,313,794 (10.02 MB)
#  Non-trainable params: 1,024 (8.00 KB)

# %%
x_true = np.linspace(x_min, x_max, 100)

# Compute theoretical |Psi(x,t)|^2 as before
def U_0(x, t):
    w = 1.0
    return np.exp(-1j * 0.5 * w * t) * (w/np.pi)**0.25 * np.exp(-w * x**2 / 2.0)

def U_1(x, t):
    w = 1.0
    return np.exp(-1j * 1.5 * w * t) * (w/np.pi)**0.25 * np.exp(-w * x**2 / 2.0) * x * np.sqrt(2.0*w)

# Define time steps
# t_test = [0, np.pi/2.0, np.pi, 2.0*np.pi]
t_test = [0, np.pi/32, np.pi/16, np.pi/4.0, np.pi/4.0+0.01]

# Create subplots
fig, axs = plt.subplots(1, len(t_test), figsize=(15, 5), sharey=True)

for i, t_val in enumerate(t_test):
    t_in = tf.ones_like(x_is) * t_val
    t_ins = scale_inputs(t_in, t_min, t_max)
    X = tf.concat([x_is, t_ins], axis=1)
    uv = loaded_model(X)
    u, v = uv[:, 0:1], uv[:, 1:2]
    # psi_Re, psi_Im = normalization(x_min, x_max, N_b, u, v)
    # density = psi_Re**2 + psi_Im**2

    t_true = np.ones_like(x_true) * t_val
    psi_true = (1.0 / np.sqrt(2.0)) * (U_0(x_true, t_true) + U_1(x_true, t_true))
    density_true = np.abs(psi_true)**2

    ax = axs[i]
    # ax.scatter(x_i, density, s=10, label="Normalized", alpha=0.7)
    ax.scatter(x_i, u**2 + v**2, s=10, label="Predicted", alpha=0.5)
    ax.scatter(x_true, density_true, s=10, label="True", alpha=0.6)
    ax.set_title(f"$t = {t_val:.2f}$")
    ax.set_xlabel("x")
    if i == 0:
        ax.set_ylabel(r"$|\Psi(x,t)|^2$")
    ax.grid(True)

# Add a single legend and adjust layout
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', ncol=2)
fig.suptitle("Predicted $|\Psi(x,t)|^2$ at Different Time Steps", fontsize=14)
# plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()
